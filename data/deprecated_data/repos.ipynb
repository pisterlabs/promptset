# %% [markdown]
# # Objectives
#
# Reference: [Patrick's Mind Map](https://excalidraw.com/#json=R3xPQDIzn6TOissiXXcTN,_v-YLa9E2v8DRoVU0-Xjdg)
#
# 1. **Search for candidate repos** (containing prompts in .py/.txt files) using:
#     - LangChain
#     - Guidance (by Microsoft)
#     - LlamaIndex
# 2. **Find Prompts**:
#     - 2.1. Filter down via dirs and files
#         - Look at dirs for 'template' or 'prompt' folders (or files)
#     - 2.2. Filter down via code search:
#         - imports some library like openai, hugginface, etc.
#         - (are they in files? Strings?
#         - How many use variables?
#         - Do they concat, use f-strings, use format? Etc.)
#
# <br />
#
# **Possible Next Steps**:
# - Skim through a random sample set of files manually
# - Run professor's [sslim check tool](https://github.com/kpister/sllim) on them (semantic analysis to detect errors in prompt files)

# %% [markdown]
# ## 📚 **Candidate Repos**

# %%
import requests, json
from pprint import pprint

def fetch_data(query="langchain+OR+GUIDANCE+OR+LlamaIndex", sort="stars", order="asc", per_page=100, language="python", star_count=4, get_fork=False):
    """
    # GitHub API URL for searching repositories
    # DOCS: https://docs.github.com/en/rest/search/search?apiVersion=2022-11-28#search-repositories

    # Params Default
    query = "langchain+OR+GUIDANCE+OR+LlamaIndex"
    sort = "stars"
    order = "asc"
    per_page = 100  # Max 100
    language = "python"
    star_count = 4  # Fetching all repos with >= 4 stars

    Returns a results dict with the following structure:
    {
        total_count: int,
        items: [{repo1_info}, {repo2_info}, ...]
    }
    """
    # Setting up result dict and file
    result = {"total_count": 0, "items": []}
    
    # NOTE: Only the first 1000 search results are available through this API
    print("Fetching all 10 pages (assuming there are >= 1000 results)")
    for page in range(1, 11):
        url = f"https://api.github.com/search/repositories?q={query}+fork:{get_fork}+language:{language}+stars:>={star_count}&sort={sort}&order={order}&per_page={per_page}&page={page}"
        # Make the API request and get the JSON response
        response = requests.get(url)
        data = response.json()
        # Check if the request was successful
        if response.status_code != 200:
            raise Exception(data.get("message", "Unknown error"))

        # Check if the API returned an error
        if "message" in data:
            raise Exception(data["message"])
        
        # Add the results to the result list and file
        result["items"].extend(data["items"])
        print(f"Page {page} done")
    
    print("Done fetching all 10 pages")

    # Add the total count to the result
    result["total_count"] = data["total_count"]

    # Store the result
    with open("repos.json", "w") as file:
        json.dump(result, file, indent=4)

    return result

# WARNING: SLOW DUE TO API rate limit (10 times per minute). Can be called only once per minute.
# More Details in the DOCS.
##################################################
# repos = fetch_data()  # UNCOMMENT WHEN NEEDED

# %% [markdown]
# ## 🔎 **Find Prompts**

# %%
from utils import get_api_key_github  # custom function for privacy. Get your own API key
import time

def search_repo(repo_name, username="DJPAUL2001", api_key=get_api_key_github()):
    """
    Searches a repo for promp or template file. HELPER FUNCTION for search_all_repos()
    Github API URL: 
    - https://docs.github.com/en/rest/search/search?apiVersion=2022-11-28#search-code
    - https://docs.github.com/en/enterprise-server@2.22/search-github/searching-on-github/searching-code
    
    When searching for code, you can get text match metadata for the file content and file path fields when you pass 
    the text-match media type. For more details about how to receive highlighted search results

    Note: The "Search code" endpoint requires you to authenticate and limits you to 10 requests per minute

    Returns a list of files. e.g. [{file1_info}, {file2_info}, ...]
    """
    query = "prompt+OR+template"
    inside = "file,path"  # Search in file content and file path
    extension = "extension:prompt+OR+extension:template+OR+extension:txt+OR+extension:py"
    url = f"https://api.github.com/search/code?q={query}+in:{inside}+{extension}+repo:{repo_name}"
    
    response = requests.get(url, auth=(username, api_key))
    data = response.json()

    # Check if the request was successful
    if response.status_code != 200:
        raise Exception(data.get("message", "Unknown error"))
    
    # Check if the API returned an error
    if "message" in data:
        raise Exception(data["message"])
    
    return data["items"]

def search_all_repos(repos, filename="repos_prompts.json", username="DJPAUL2001", api_key=get_api_key_github()):
    """
    Running search_repo() on all candidate repos in repos.json. Approx runtime: > 1 hr 40 mins (took 115 mins)

    Returns a dict with the following structure:
    {
        repo_name1: [{file1_info}, {file2_info}, ...],
        repo_name2: [{file1_info}, {file2_info}, ...],
        ...
    }
    """
    # Searching for prompt or template files in each repo
    repos_prompts = {}
    for repo in repos["items"]:
        repo_name = repo["full_name"]
        try:
            repos_prompts[repo_name] = search_repo(repo_name, username, api_key)
        except Exception as e:
            print(f"Error: {e}")
            # Assuming the exception is due to rate limit, wait for 1 minute and try again
            time.sleep(60)
            repos_prompts[repo_name] = search_repo(repo_name, username, api_key)

    # STORING RESULT 
    ##################################################
    with open(filename, "w") as file:
        json.dump(repos_prompts, file, indent=4)
    
    return repos_prompts

# WARNING: SLOW DUE TO API rate limit (10 times per minute). Can be called only once per 2 hrs.
# More Details in the DOCS.
# with open("repos_>=4stars.json", "r") as file:
#     repos = json.load(file)
# repos_prompts_2 = search_all_repos(repos)  # UNCOMMENT WHEN NEEDED

# %% [markdown]
# 🗨️ Number of Repos with Prompts

# %%
def get_reposWithPrompt_count(repos_prompts_filename):
    """
    Counts the number of repos with prompt/template search results
    """
    # Loading prompts search results from all repos
    with open(repos_prompts_filename, "r") as file:
        repos_prompts = json.load(file)

    # Counting number of repos with prompt/template search results
    count = 0
    total_files = 0
    for repo_name, files in repos_prompts.items():
        if len(files) > 0:
            count += 1
            total_files += len(files)

    print(f"ReposWithPrompts Count in {repos_prompts_filename}: {count} out of {len(repos_prompts)}, {total_files} files")

get_reposWithPrompt_count("repos_prompts_>=0stars.json")
get_reposWithPrompt_count("repos_prompts_>=4stars.json")
# Out:
# ReposWithPrompts Count in repos_prompts_>=0stars.json: 108 out of 1000, 635 files
# ReposWithPrompts Count in repos_prompts_>=4stars.json: 372 out of 981, 1444 files

# %% [markdown]
# 📂 Grabbing and Storing all raw file URLs in one place

# %%
def get_rawFileURL(read_filename="repos_prompts.json", write_filename="repo_to_rawFileURL.json"):
    """
    To get raw file content of repos_prompts files, do the following: 
    1. grab the html_url of a code_search item
    2. remove blob/
    3. replace with github.com with raw.githubusercontent.com

    e.g.
    res = requests.get('https://raw.githubusercontent.com/langchain-ai/langchain/98aff29fbda6bcb99ea6af0cfd1532954b504bdc/libs/langchain/langchain/schema/prompt_template.py')
    print(res.text)

    
    Returns a dict with the following structure (Note: Only contains repos with prompt/template files):
    {
        repo_name1: [file_raw_url1, file_raw_url2, ...],
        repo_name2: [file_raw_url1, file_raw_url2, ...],
        ...
    }
    """
    # Loading prompts search results from all repos
    with open(read_filename, "r") as file:
        repos_prompts = json.load(file)

    # Getting raw file URL
    repo_to_fileURL = {}
    for repo, files in repos_prompts.items():
        for file in files:
            file_raw_url = file["html_url"].replace("blob/", "").replace("github.com", "raw.githubusercontent.com")
            repo_to_fileURL[repo] = repo_to_fileURL.get(repo, []) + [file_raw_url]

    # STORING RESULT
    with open(write_filename, "w") as file:
        json.dump(repo_to_fileURL, file, indent=4)

    return repo_to_fileURL

get_rawFileURL("repos_prompts_>=0stars.json", "repo_to_rawFileURL_>=0stars.json")
get_rawFileURL("repos_prompts_>=4stars.json", "repo_to_rawFileURL_>=4stars.json")
# Out:
# {'pprados/langchain-googledrive': ['https://raw.githubusercontent.com/pprados/langchain-googledrive/562a3d29bb3ca1ca3a432662087d83b734bc25c2/langchain_googledrive/document_loaders/google_drive.py',
#   'https://raw.githubusercontent.com/pprados/langchain-googledrive/562a3d29bb3ca1ca3a432662087d83b734bc25c2/langchain_googledrive/utilities/google_drive.py',
#   'https://raw.githubusercontent.com/pprados/langchain-googledrive/562a3d29bb3ca1ca3a432662087d83b734bc25c2/tests/integration_tests/document_loaders/test_google_drive.py',
#   'https://raw.githubusercontent.com/pprados/langchain-googledrive/562a3d29bb3ca1ca3a432662087d83b734bc25c2/tests/integration_tests/providers/test_google_drive.py',
#   'https://raw.githubusercontent.com/pprados/langchain-googledrive/562a3d29bb3ca1ca3a432662087d83b734bc25c2/tests/unit_tests/utilities/test_google_drive.py',
#   'https://raw.githubusercontent.com/pprados/langchain-googledrive/562a3d29bb3ca1ca3a432662087d83b734bc25c2/tests/unit_tests/document_loaders/test_google_drive.py'],
#  'lwangreen/Langchain-ChatGLM': ['https://raw.githubusercontent.com/lwangreen/Langchain-ChatGLM/cc31708e0a36e4228d2f7694168970cf323f3626/chains/local_doc_qa.py',
#   'https://raw.githubusercontent.com/lwangreen/Langchain-ChatGLM/cc31708e0a36e4228d2f7694168970cf323f3626/server/chat/search_engine_chat.py',
#   'https://raw.githubusercontent.com/lwangreen/Langchain-ChatGLM/cc31708e0a36e4228d2f7694168970cf323f3626/models/fastchat_openai_llm.py',
#   'https://raw.githubusercontent.com/lwangreen/Langchain-ChatGLM/cc31708e0a36e4228d2f7694168970cf323f3626/chains/llmchain_with_history.py',
#   'https://raw.githubusercontent.com/lwangreen/Langchain-ChatGLM/cc31708e0a36e4228d2f7694168970cf323f3626/server/chat/chat.py',
#   'https://raw.githubusercontent.com/lwangreen/Langchain-ChatGLM/cc31708e0a36e4228d2f7694168970cf323f3626/configs/model_config.py',
#   'https://raw.githubusercontent.com/lwangreen/Langchain-ChatGLM/cc31708e0a36e4228d2f7694168970cf323f3626/server/chat/knowledge_base_chat.py'],
#  'avrabyt/MultiLingual-ChatBot': ['https://raw.githubusercontent.com/avrabyt/MultiLingual-ChatBot/34c54805650361800c14019a20338a9e0f1db228/app.py'],
#  'amosjyng/langchain-contrib': ['https://raw.githubusercontent.com/amosjyng/langchain-contrib/ef3569455bbb535ccca0e62e2051a1171f320bc8/langchain_contrib/prompts/choice/template.py',
#   'https://raw.githubusercontent.com/amosjyng/langchain-contrib/ef3569455bbb535ccca0e62e2051a1171f320bc8/langchain_contrib/chains/mrkl/prompt.py',
#   'https://raw.githubusercontent.com/amosjyng/langchain-contrib/ef3569455bbb535ccca0e62e2051a1171f320bc8/langchain_contrib/prompts/z_base.py',
#   'https://raw.githubusercontent.com/amosjyng/langchain-contrib/ef3569455bbb535ccca0e62e2051a1171f320bc8/langchain_contrib/prompts/schema.py',
#   'https://raw.githubusercontent.com/amosjyng/langchain-contrib/ef3569455bbb535ccca0e62e2051a1171f320bc8/langchain_contrib/prompts/chained.py',
#   'https://raw.githubusercontent.com/amosjyng/langchain-contrib/ef3569455bbb535ccca0e62e2051a1171f320bc8/langchain_contrib/prompts/prefixed.py',
#   'https://raw.githubusercontent.com/amosjyng/langchain-contrib/ef3569455bbb535ccca0e62e2051a1171f320bc8/langchain_contrib/prompts/choice/__init__.py',
#   'https://raw.githubusercontent.com/amosjyng/langchain-contrib/ef3569455bbb535ccca0e62e2051a1171f320bc8/langchain_contrib/tools/terminal/safety.py',
#   'https://raw.githubusercontent.com/amosjyng/langchain-contrib/ef3569455bbb535ccca0e62e2051a1171f320bc8/langchain_contrib/prompts/dummy.py',
#   'https://raw.githubusercontent.com/amosjyng/langchain-contrib/ef3569455bbb535ccca0e62e2051a1171f320bc8/langchain_contrib/chains/mrkl/pick_action.py',
#   'https://raw.githubusercontent.com/amosjyng/langchain-contrib/ef3569455bbb535ccca0e62e2051a1171f320bc8/langchain_contrib/utils/safe.py',
#   'https://raw.githubusercontent.com/amosjyng/langchain-contrib/ef3569455bbb535ccca0e62e2051a1171f320bc8/langchain_contrib/chains/dummy.py',
#   'https://raw.githubusercontent.com/amosjyng/langchain-contrib/ef3569455bbb535ccca0e62e2051a1171f320bc8/langchain_contrib/prompts/__init__.py',
#   'https://raw.githubusercontent.com/amosjyng/langchain-contrib/ef3569455bbb535ccca0e62e2051a1171f320bc8/langchain_contrib/chains/mrkl/choice.py',
#   'https://raw.githubusercontent.com/amosjyng/langchain-contrib/ef3569455bbb535ccca0e62e2051a1171f320bc8/langchain_contrib/agents/dummy.py',
#   'https://raw.githubusercontent.com/amosjyng/langchain-contrib/ef3569455bbb535ccca0e62e2051a1171f320bc8/tests/prompts/test_choice.py',
#   'https://raw.githubusercontent.com/amosjyng/langchain-contrib/ef3569455bbb535ccca0e62e2051a1171f320bc8/tests/prompts/test_z_base.py',
#   'https://raw.githubusercontent.com/amosjyng/langchain-contrib/ef3569455bbb535ccca0e62e2051a1171f320bc8/tests/prompts/test_chained.py',
#   'https://raw.githubusercontent.com/amosjyng/langchain-contrib/ef3569455bbb535ccca0e62e2051a1171f320bc8/tests/llms/test_human_choice.py',
#   'https://raw.githubusercontent.com/amosjyng/langchain-contrib/ef3569455bbb535ccca0e62e2051a1171f320bc8/tests/prompts/test_prefixed.py'],
#  'Sayvai-io/custom-tools': ['https://raw.githubusercontent.com/Sayvai-io/custom-tools/b19bfbbd6400c5e072ce7c82cae432bfac1d0cca/src/sayvai_tools/tools/sql_database/prompt.py',
#   'https://raw.githubusercontent.com/Sayvai-io/custom-tools/b19bfbbd6400c5e072ce7c82cae432bfac1d0cca/src/sayvai_tools/utils/database/dbchain.py',
#   'https://raw.githubusercontent.com/Sayvai-io/custom-tools/b19bfbbd6400c5e072ce7c82cae432bfac1d0cca/src/sayvai_tools/tools/sql_database/tool.py'],
#  'Joentze/chad-bod': ['https://raw.githubusercontent.com/Joentze/chad-bod/e7a2c82a99b64472aaa9253df936a2ecf07c4180/prompts.py'],
#  'micheldumontier/sparql-langchain': ['https://raw.githubusercontent.com/micheldumontier/sparql-langchain/55c33cc9336ef0618e46ba01470d9c028f6deb7c/src/sparqlchain.py'],
#  'staticTao/langchain_llm_demo': ['https://raw.githubusercontent.com/staticTao/langchain_llm_demo/fd07e019d187a4a4b219b758b033d91d7ce5002b/polymerization_ai.py',
#   'https://raw.githubusercontent.com/staticTao/langchain_llm_demo/fd07e019d187a4a4b219b758b033d91d7ce5002b/polymerization_ai_func.py'],
#  'Ayyodeji/Langchain-LLM-PDF-QA': ['https://raw.githubusercontent.com/Ayyodeji/Langchain-LLM-PDF-QA/cad7113536ef9f3c8e469084c590c65ffe996408/app/prompts.py'],
#  'SSK-14/chatbot-guardrails': ['https://raw.githubusercontent.com/SSK-14/chatbot-guardrails/4ee7b7783cd479fa7a36cafe2fd3a94641c2b082/app.py'],
#  'huqianghui/pdf2MySQLByLangchain': ['https://raw.githubusercontent.com/huqianghui/pdf2MySQLByLangchain/b47af4f897efafc9937f23866b844a77133168b6/template/systemTemplate.py',
#   'https://raw.githubusercontent.com/huqianghui/pdf2MySQLByLangchain/b47af4f897efafc9937f23866b844a77133168b6/template/azure_open_AI_instance.py',
#   'https://raw.githubusercontent.com/huqianghui/pdf2MySQLByLangchain/b47af4f897efafc9937f23866b844a77133168b6/template/fewshot1.py',
#   'https://raw.githubusercontent.com/huqianghui/pdf2MySQLByLangchain/b47af4f897efafc9937f23866b844a77133168b6/template/fewshot2.py',
#   'https://raw.githubusercontent.com/huqianghui/pdf2MySQLByLangchain/b47af4f897efafc9937f23866b844a77133168b6/template/fewshot5.py',
#   'https://raw.githubusercontent.com/huqianghui/pdf2MySQLByLangchain/b47af4f897efafc9937f23866b844a77133168b6/template/fewshot3.py',
#   'https://raw.githubusercontent.com/huqianghui/pdf2MySQLByLangchain/b47af4f897efafc9937f23866b844a77133168b6/template/fewshot4.py'],
#  'sekihan02/UI_for_personal_use_ChatGPTAPI': ['https://raw.githubusercontent.com/sekihan02/UI_for_personal_use_ChatGPTAPI/3601872f2334da279e1a90483bc2d77e26ad66a0/app/routes/text_correction.py',
#   'https://raw.githubusercontent.com/sekihan02/UI_for_personal_use_ChatGPTAPI/3601872f2334da279e1a90483bc2d77e26ad66a0/app/routes/chat.py'],
#  'davidshtian/Bedrock-ChatBot-with-LangChain-and-Streamlit': ['https://raw.githubusercontent.com/davidshtian/Bedrock-ChatBot-with-LangChain-and-Streamlit/9ce60e0fe2cccfe58c0d93bfc635be253277484c/simple/bedrock_chatbot.py',
#   'https://raw.githubusercontent.com/davidshtian/Bedrock-ChatBot-with-LangChain-and-Streamlit/9ce60e0fe2cccfe58c0d93bfc635be253277484c/streaming/bedrock_simple.py'],
#  'ibizabroker/gpt-pdf-bot': ['https://raw.githubusercontent.com/ibizabroker/gpt-pdf-bot/c8d2f0ccab36db7a80aeb5459e1ff32addaaab86/chain.py'],
#  'KareEnges/ToolGPT': ['https://raw.githubusercontent.com/KareEnges/ToolGPT/bf749e0e5fb44c54b959179ab9b891ca99773b63/main.py'],
#  'americium-241/Omnitool_UI': ['https://raw.githubusercontent.com/americium-241/Omnitool_UI/44914faf43cb95cf9ddadb70ae463e67814fefc0/tools/tools_list/tools_list.py',
#   'https://raw.githubusercontent.com/americium-241/Omnitool_UI/44914faf43cb95cf9ddadb70ae463e67814fefc0/ui/info_ui.py',
#   'https://raw.githubusercontent.com/americium-241/Omnitool_UI/44914faf43cb95cf9ddadb70ae463e67814fefc0/agents/agents_list/new_agent.py'],
#  'AAAATTIEH/auto-chain': ['https://raw.githubusercontent.com/AAAATTIEH/auto-chain/48b2456f6e123befb83f41bb30e2500a26d7e234/models/tools/summarize_file.py',
#   'https://raw.githubusercontent.com/AAAATTIEH/auto-chain/48b2456f6e123befb83f41bb30e2500a26d7e234/models/tools/file_path_finder.py',
#   'https://raw.githubusercontent.com/AAAATTIEH/auto-chain/48b2456f6e123befb83f41bb30e2500a26d7e234/models/tools/image_path_finder.py'],
#  'petermartens98/OpenAI-LangChain-Movie-Concept-and-DALLE2-Poster-Generation-Streamlit-Web-App': ['https://raw.githubusercontent.com/petermartens98/OpenAI-LangChain-Movie-Concept-and-DALLE2-Poster-Generation-Streamlit-Web-App/822435a4f305d9468fbd77c1a63613fc609a1cfa/AppV2/prompts.py',
#   'https://raw.githubusercontent.com/petermartens98/OpenAI-LangChain-Movie-Concept-and-DALLE2-Poster-Generation-Streamlit-Web-App/822435a4f305d9468fbd77c1a63613fc609a1cfa/AppV1/main.py',
#   'https://raw.githubusercontent.com/petermartens98/OpenAI-LangChain-Movie-Concept-and-DALLE2-Poster-Generation-Streamlit-Web-App/822435a4f305d9468fbd77c1a63613fc609a1cfa/AppV2/main.py'],
#  'Amanastel/llm_project': ['https://raw.githubusercontent.com/Amanastel/llm_project/4430b3372316ca36f094f52e8312efb30ec8c0ff/LLMS_langchain/example.py'],
#  'tdolan21/miniAGI': ['https://raw.githubusercontent.com/tdolan21/miniAGI/caf64d1bac8b32faeeffe269335f7f7345479a3d/pages/agent_configuration.py',
#   'https://raw.githubusercontent.com/tdolan21/miniAGI/caf64d1bac8b32faeeffe269335f7f7345479a3d/pages/huggingface_agi.py',
#   'https://raw.githubusercontent.com/tdolan21/miniAGI/caf64d1bac8b32faeeffe269335f7f7345479a3d/requirements.txt'],
#  'sejaldua/inquizitive': ['https://raw.githubusercontent.com/sejaldua/inquizitive/9019eea24b03a8ee6331af9e58d35f0641f72e7f/chat.py',
#   'https://raw.githubusercontent.com/sejaldua/inquizitive/9019eea24b03a8ee6331af9e58d35f0641f72e7f/constants.py'],
#  'Elite-AI-August/PDF-Pilot': ['https://raw.githubusercontent.com/Elite-AI-August/PDF-Pilot/d60fe1d38561c8267c7e654ee33dac4d2c4df929/Developers/Basic-dev-Scripts/Langchain-QA-dev.py'],
#  'iamarunbrahma/youtube-ai-assistant': ['https://raw.githubusercontent.com/iamarunbrahma/youtube-ai-assistant/502f5294efc84c56b2730fe8844065eeb9b8739d/app.py'],
#  'chrimage/summarybot-16k': ['https://raw.githubusercontent.com/chrimage/summarybot-16k/532154bf88833ba48e921842a82bacedd592b63c/summarizer.py'],
#  'admineral/PDF-Pilot': ['https://raw.githubusercontent.com/admineral/PDF-Pilot/0167d50360c961bf4d3bb31e3f13d30a2370550c/Developers/Basic-dev-Scripts/Langchain-QA-dev.py'],
#  'CharlesSQ/conversational-agent-with-QA-tool': ['https://raw.githubusercontent.com/CharlesSQ/conversational-agent-with-QA-tool/171a2afaafecdd6265a72dc0c82afdc436f91d08/prompt_template.py',
#   'https://raw.githubusercontent.com/CharlesSQ/conversational-agent-with-QA-tool/171a2afaafecdd6265a72dc0c82afdc436f91d08/app.py'],
#  'shvuuuu/mailpad': ['https://raw.githubusercontent.com/shvuuuu/mailpad/810a02620ae44ba82d9d718c49e18d1882945079/mailpad/mailAI.py'],
#  'DataCTE/Camel-local': ['https://raw.githubusercontent.com/DataCTE/Camel-local/af5dfc83568779718378a99363727ce3e6b2e0a6/Camel-localmodel.py'],
#  'DJcodess/Flipchat': ['https://raw.githubusercontent.com/DJcodess/Flipchat/4d6eab853a9acf53648009292334d676bbcee851/chatbot.py'],
#  'CharlyWargnier/LangchainRAG-Trubrics-Langsmith': ['https://raw.githubusercontent.com/CharlyWargnier/LangchainRAG-Trubrics-Langsmith/09609be002109f0eb7794665e1173be06d510b4f/vanilla_chain.py'],
#  'adityabrahmankar/PDF-Chat': ['https://raw.githubusercontent.com/adityabrahmankar/PDF-Chat/04e67422a8ffd06de79918e3f4073d08a02f3ef4/app.py'],
#  'os1ma/LlamaIndex-Text-to-SQL-100-knocks': ['https://raw.githubusercontent.com/os1ma/LlamaIndex-Text-to-SQL-100-knocks/36d79403f97e944e7e258d0c3aefea052d8fa749/llamaindex_text_to_sql_100_knocks/main_without_schema.py'],
#  'devsapp/fc-langchain-chatglm6b': ['https://raw.githubusercontent.com/devsapp/fc-langchain-chatglm6b/d9049e3fe216038a694ce9b48dc546ab9dc9bfb8/src/code/chatglm6b-resource/chains/local_doc_qa.py',
#   'https://raw.githubusercontent.com/devsapp/fc-langchain-chatglm6b/d9049e3fe216038a694ce9b48dc546ab9dc9bfb8/src/code/chatglm6b-resource/configs/model_config.py'],
#  'Syed007Hassan/Langchain': ['https://raw.githubusercontent.com/Syed007Hassan/Langchain/c92127eb771886fa929d73179b0ad35db63208c5/VECTORSTORE-CHAT/archive/chain.py'],
#  'sivasurend/langchain_utilities': ['https://raw.githubusercontent.com/sivasurend/langchain_utilities/88998bde8932b142c0a11f0d492e9d12e85ac556/herogpt_langchain.py',
#   'https://raw.githubusercontent.com/sivasurend/langchain_utilities/88998bde8932b142c0a11f0d492e9d12e85ac556/langchain%20web%20page%20search.txt',
#   'https://raw.githubusercontent.com/sivasurend/langchain_utilities/88998bde8932b142c0a11f0d492e9d12e85ac556/replace_string_in_csv.py'],
#  'Ramseths/app-llama2': ['https://raw.githubusercontent.com/Ramseths/app-llama2/ae6fbcef045fd0a53432bc47319252a2105a98b1/model.py'],
#  'techwithtim/LangChain-Quick-Start': ['https://raw.githubusercontent.com/techwithtim/LangChain-Quick-Start/1c35bdac503a96040236a0c8587400c665f3a93c/prompt_template.py',
#   'https://raw.githubusercontent.com/techwithtim/LangChain-Quick-Start/1c35bdac503a96040236a0c8587400c665f3a93c/chain.py',
#   'https://raw.githubusercontent.com/techwithtim/LangChain-Quick-Start/1c35bdac503a96040236a0c8587400c665f3a93c/output_parser.py'],
#  'Coding-Crashkurse/LangChain-Discord-Bot': ['https://raw.githubusercontent.com/Coding-Crashkurse/LangChain-Discord-Bot/c79d0fc3a26d4b46371a594b9617717b9d405c57/bot.py'],
#  'Magic-Emerge/know-more': ['https://raw.githubusercontent.com/Magic-Emerge/know-more/90dcf94284befb5da6d5134f4421cec611b30aaa/app/prompts/map_rerank_prompts_extends.py',
#   'https://raw.githubusercontent.com/Magic-Emerge/know-more/90dcf94284befb5da6d5134f4421cec611b30aaa/app/prompts/map_reduce_prompts_extends.py',
#   'https://raw.githubusercontent.com/Magic-Emerge/know-more/90dcf94284befb5da6d5134f4421cec611b30aaa/app/prompts/prompts.py',
#   'https://raw.githubusercontent.com/Magic-Emerge/know-more/90dcf94284befb5da6d5134f4421cec611b30aaa/app/prompts/stuff_prompts_extends.py',
#   'https://raw.githubusercontent.com/Magic-Emerge/know-more/90dcf94284befb5da6d5134f4421cec611b30aaa/app/prompts/refine_prompts_extends.py',
#   'https://raw.githubusercontent.com/Magic-Emerge/know-more/90dcf94284befb5da6d5134f4421cec611b30aaa/archive/chain.py'],
#  'clairelovesgravy/slack_bot_demo': ['https://raw.githubusercontent.com/clairelovesgravy/slack_bot_demo/627cf95d2455a634f82878847142f134fe4eee0b/app.py'],
#  'ma2za/docqa-stream': ['https://raw.githubusercontent.com/ma2za/docqa-stream/8fac33ef7a472ed7e8148f9f2ba726e66dbd5e9d/src/docqa_stream/services/files.py'],
#  'yaohui-wyh/blog_gpt': ['https://raw.githubusercontent.com/yaohui-wyh/blog_gpt/00356003644cdd32fb2f83bd9b1e37eaffb5905c/blog_gpt/blog_gpt.py'],
#  'mattshax/ipagent': ['https://raw.githubusercontent.com/mattshax/ipagent/d73d5607de806418993011026a463b74594dff8e/app/modules/chatbot.py'],
#  'benbaker76/FlaskGPT': ['https://raw.githubusercontent.com/benbaker76/FlaskGPT/5c07c541b05cf45320a634bfb4c8e649edcb5f2a/FlaskGPT.py'],
#  'IOriens/whisper-video': ['https://raw.githubusercontent.com/IOriens/whisper-video/6c75494d97d9fe05e861e740bfa1b7b8f22e322e/main.py'],
#  'Bi-Mars/persona_builder': ['https://raw.githubusercontent.com/Bi-Mars/persona_builder/4e32b4b81c9e882a9a5d4e27039a3fbca8457b6f/profile_extractor/ice_breaker.py',
#   'https://raw.githubusercontent.com/Bi-Mars/persona_builder/4e32b4b81c9e882a9a5d4e27039a3fbca8457b6f/profile_extractor/agents/twitter_lookup_agent.py',
#   'https://raw.githubusercontent.com/Bi-Mars/persona_builder/4e32b4b81c9e882a9a5d4e27039a3fbca8457b6f/profile_extractor/agents/linkedin_lookup_agents.py'],
#  'glandaDarie/linkedIn-recruiter-reply-bot': ['https://raw.githubusercontent.com/glandaDarie/linkedIn-recruiter-reply-bot/0f92226a97dd3b9e15a9d9e30c653f6fde8221e3/automation/recruiter_text_replier/hugging_face.py'],
#  'Tom-A-Roberts/LangQuest': ['https://raw.githubusercontent.com/Tom-A-Roberts/LangQuest/c1cb201f1ec7806b2a9237733c58a08de4ff2761/image_generator.py',
#   'https://raw.githubusercontent.com/Tom-A-Roberts/LangQuest/c1cb201f1ec7806b2a9237733c58a08de4ff2761/langchain_functions.py'],
#  'gutfeeling/langsearch': ['https://raw.githubusercontent.com/gutfeeling/langsearch/0e963233f37d168ee3295a6f9d133582a6246baa/langsearch/chains/qa.py',
#   'https://raw.githubusercontent.com/gutfeeling/langsearch/0e963233f37d168ee3295a6f9d133582a6246baa/langsearch/pipelines/common/summary_index.py',
#   'https://raw.githubusercontent.com/gutfeeling/langsearch/0e963233f37d168ee3295a6f9d133582a6246baa/langsearch/pipelines/common/mixins/summary.py',
#   'https://raw.githubusercontent.com/gutfeeling/langsearch/0e963233f37d168ee3295a6f9d133582a6246baa/examples/local_files/webapp/pages/HYDE_Demo.py',
#   'https://raw.githubusercontent.com/gutfeeling/langsearch/0e963233f37d168ee3295a6f9d133582a6246baa/examples/local_files/webapp/pages/Simple_QA_Demo.py'],
#  'IbrahimSobh/askdoc': ['https://raw.githubusercontent.com/IbrahimSobh/askdoc/af8ed15a861a83dd13085312f2c107e9fc478e86/streamlit_app.py'],
#  'geraltofrivia/fewshot-textclassification': ['https://raw.githubusercontent.com/geraltofrivia/fewshot-textclassification/1d20a00873e115416da1033293222f962549a0d7/main.py'],
#  'aahouzi/llama2-chatbot-cpu': ['https://raw.githubusercontent.com/aahouzi/llama2-chatbot-cpu/87489eb832ba3ae4cc0022279eb492580b269e42/app/app.py'],
#  'rishabkumar7/youtube-assistant-langchain': ['https://raw.githubusercontent.com/rishabkumar7/youtube-assistant-langchain/cf56624bebccde528590ec6285bfb3e0c7a8c2fc/langchain_helper.py'],
#  'ravsau/langchain-notes': ['https://raw.githubusercontent.com/ravsau/langchain-notes/280506c016dc665445f270a0713f418ee49054a1/local-llama-langchain/llama_langchain.py'],
#  'harukaxq/langchain-book': ['https://raw.githubusercontent.com/harukaxq/langchain-book/074ad3fb23c1f50ffe4a2fa6d2adc7941af912f2/02_mode_io/prompt_template_from_template_save_sample.py',
#   'https://raw.githubusercontent.com/harukaxq/langchain-book/074ad3fb23c1f50ffe4a2fa6d2adc7941af912f2/02_mode_io/prompt_template_from_template_load_sample.py',
#   'https://raw.githubusercontent.com/harukaxq/langchain-book/074ad3fb23c1f50ffe4a2fa6d2adc7941af912f2/02_mode_io/prompt.py',
#   'https://raw.githubusercontent.com/harukaxq/langchain-book/074ad3fb23c1f50ffe4a2fa6d2adc7941af912f2/03_retrieval/chat_2.py',
#   'https://raw.githubusercontent.com/harukaxq/langchain-book/074ad3fb23c1f50ffe4a2fa6d2adc7941af912f2/03_retrieval/query_2.py',
#   'https://raw.githubusercontent.com/harukaxq/langchain-book/074ad3fb23c1f50ffe4a2fa6d2adc7941af912f2/05_chain/llmchain.py',
#   'https://raw.githubusercontent.com/harukaxq/langchain-book/074ad3fb23c1f50ffe4a2fa6d2adc7941af912f2/05_chain/request_chain.py',
#   'https://raw.githubusercontent.com/harukaxq/langchain-book/074ad3fb23c1f50ffe4a2fa6d2adc7941af912f2/02_mode_io/model_io_few_shot.py',
#   'https://raw.githubusercontent.com/harukaxq/langchain-book/074ad3fb23c1f50ffe4a2fa6d2adc7941af912f2/02_mode_io/datetime_output_parser.py',
#   'https://raw.githubusercontent.com/harukaxq/langchain-book/074ad3fb23c1f50ffe4a2fa6d2adc7941af912f2/02_mode_io/prompt_and_language_model.py',
#   'https://raw.githubusercontent.com/harukaxq/langchain-book/074ad3fb23c1f50ffe4a2fa6d2adc7941af912f2/03_retrieval/re_phrase_query.py',
#   'https://raw.githubusercontent.com/harukaxq/langchain-book/074ad3fb23c1f50ffe4a2fa6d2adc7941af912f2/03_retrieval/chat_3.py',
#   'https://raw.githubusercontent.com/harukaxq/langchain-book/074ad3fb23c1f50ffe4a2fa6d2adc7941af912f2/05_chain/sequential_chain.py'],
#  '836304831/langchain-anal': ['https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/schema/prompt_template.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/chains/query_constructor/prompt.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/evaluation/qa/eval_prompt.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/chains/router/multi_prompt.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/evaluation/agents/trajectory_eval_prompt.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/chains/qa_with_sources/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/agents/react/wiki_prompt.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/chains/question_answering/map_rerank_prompt.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/agents/agent_toolkits/openapi/planner_prompt.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/chains/prompt_selector.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/memory/prompt.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/prompts/example_selector/ngram_overlap.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/chains/graph_qa/prompts.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/agents/react/textworld_prompt.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/chains/router/multi_retrieval_prompt.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/prompts/base.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/chains/question_answering/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/chains/qa_with_sources/stuff_prompt.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/indexes/prompts/entity_extraction.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/indexes/prompts/entity_summarization.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/chains/router/multi_prompt_prompt.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/chains/pal/colored_object_prompt.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/prompts/few_shot_with_templates.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/chains/pal/math_prompt.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/example_generator.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/evaluation/qa/generate_prompt.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/tools/spark_sql/tool.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/memory/entity.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/llms/databricks.py',
#   'https://raw.githubusercontent.com/836304831/langchain-anal/ac7500fcf2b16ab1e771b86506ac4676d4ea93dc/langchain/smith/evaluation/config.py'],
#  'toanpv-0639/langchain-demo': ['https://raw.githubusercontent.com/toanpv-0639/langchain-demo/c9f799d120228e1261253493c220554c24a23cc6/prompts-demo.py',
#   'https://raw.githubusercontent.com/toanpv-0639/langchain-demo/c9f799d120228e1261253493c220554c24a23cc6/chains-demo.py'],
#  'Umi7899/langchain-ChatGLM-My': ['https://raw.githubusercontent.com/Umi7899/langchain-ChatGLM-My/f66c292584dbd5535fa9c7cd58342bc6cde54d5f/chains/dialogue_answering/prompts.py',
#   'https://raw.githubusercontent.com/Umi7899/langchain-ChatGLM-My/f66c292584dbd5535fa9c7cd58342bc6cde54d5f/chains/local_doc_qa.py',
#   'https://raw.githubusercontent.com/Umi7899/langchain-ChatGLM-My/f66c292584dbd5535fa9c7cd58342bc6cde54d5f/chains/dialogue_answering/base.py',
#   'https://raw.githubusercontent.com/Umi7899/langchain-ChatGLM-My/f66c292584dbd5535fa9c7cd58342bc6cde54d5f/agent/custom_agent.py',
#   'https://raw.githubusercontent.com/Umi7899/langchain-ChatGLM-My/f66c292584dbd5535fa9c7cd58342bc6cde54d5f/models/fastchat_openai_llm.py',
#   'https://raw.githubusercontent.com/Umi7899/langchain-ChatGLM-My/f66c292584dbd5535fa9c7cd58342bc6cde54d5f/configs/model_config.py',
#   'https://raw.githubusercontent.com/Umi7899/langchain-ChatGLM-My/f66c292584dbd5535fa9c7cd58342bc6cde54d5f/test/models/test_vicuna_chain_agent.py'],
#  'ossirytk/llama-cpp-langchain-chat': ['https://raw.githubusercontent.com/ossirytk/llama-cpp-langchain-chat/f21959510abfa8e0f0611cbbd430757dd25abfd8/src/llama_cpp_langchain_chat/__init__.py'],
#  'LiamConnell/codelabyrinth': ['https://raw.githubusercontent.com/LiamConnell/codelabyrinth/863c71d2325fba84ad22c85bf5cb7b1a76be261d/coder/vectorstore.py',
#   'https://raw.githubusercontent.com/LiamConnell/codelabyrinth/863c71d2325fba84ad22c85bf5cb7b1a76be261d/coder/agents/qa_with_vectorstore.py',
#   'https://raw.githubusercontent.com/LiamConnell/codelabyrinth/863c71d2325fba84ad22c85bf5cb7b1a76be261d/coder/agents/qa_multi_vectorstore.py',
#   'https://raw.githubusercontent.com/LiamConnell/codelabyrinth/863c71d2325fba84ad22c85bf5cb7b1a76be261d/coder/agents/qa_vectorstore_evaluate.py'],
#  'ConnectAI-E/DataChat-API': ['https://raw.githubusercontent.com/ConnectAI-E/DataChat-API/da1c59d2c43b8e9f38f1c896ba3f58ec21e8454b/server/models.py'],
#  'RareMojo/discord-ai': ['https://raw.githubusercontent.com/RareMojo/discord-ai/d40240c098abc57b4b71ebf8eeb9c0dc4e5bfc3f/utils/ai.py'],
#  'samvas-codes/cspm-gpt': ['https://raw.githubusercontent.com/samvas-codes/cspm-gpt/778c16a59c40a1017a30a3a63d500e77db05d36d/graphqa-chain.py'],
#  'ausboss/DiscordLangAgent': ['https://raw.githubusercontent.com/ausboss/DiscordLangAgent/58a7289a49864fdadb3a70d8a106b2fc92c2ee7b/cogs/pygbot.py',
#   'https://raw.githubusercontent.com/ausboss/DiscordLangAgent/58a7289a49864fdadb3a70d8a106b2fc92c2ee7b/cogs/youtubesummarize.py'],
#  'neobundy/pippaGPT': ['https://raw.githubusercontent.com/neobundy/pippaGPT/1219eeb77fb1758c925d3840e7bdcf1b3415f6a0/vectordb.py',
#   'https://raw.githubusercontent.com/neobundy/pippaGPT/1219eeb77fb1758c925d3840e7bdcf1b3415f6a0/agents.py',
#   'https://raw.githubusercontent.com/neobundy/pippaGPT/1219eeb77fb1758c925d3840e7bdcf1b3415f6a0/settings_sample.py',
#   'https://raw.githubusercontent.com/neobundy/pippaGPT/1219eeb77fb1758c925d3840e7bdcf1b3415f6a0/main.py'],
#  'natelalor/AI_report_generator': ['https://raw.githubusercontent.com/natelalor/AI_report_generator/6e8cac303fec39ee7ba51c795fc9fc49339a2735/supabase_prompt_builder.py',
#   'https://raw.githubusercontent.com/natelalor/AI_report_generator/6e8cac303fec39ee7ba51c795fc9fc49339a2735/shallow_langchain_report.py',
#   'https://raw.githubusercontent.com/natelalor/AI_report_generator/6e8cac303fec39ee7ba51c795fc9fc49339a2735/shallow_langchain_report_with_audio.py'],
#  'Saik0s/SwiftDocAutomator': ['https://raw.githubusercontent.com/Saik0s/SwiftDocAutomator/7c7fb8d2ac1075d4d4db98d64cf211922c269332/summarize.py'],
#  'ikram-shah/iris-fhir-transcribe-summarize-export': ['https://raw.githubusercontent.com/ikram-shah/iris-fhir-transcribe-summarize-export/8813985e556853407f59e7c636784be4ca731320/src/python/documentexport.py'],
#  'Antony90/arxiv-discord': ['https://raw.githubusercontent.com/Antony90/arxiv-discord/9039612c5d346ab489e3c85e50b7f6f86a6348f4/ai/prompts.py',
#   'https://raw.githubusercontent.com/Antony90/arxiv-discord/9039612c5d346ab489e3c85e50b7f6f86a6348f4/ai/tools.py',
#   'https://raw.githubusercontent.com/Antony90/arxiv-discord/9039612c5d346ab489e3c85e50b7f6f86a6348f4/ai/agent.py'],
#  'joshuasundance-swca/langchain-streamlit-demo': ['https://raw.githubusercontent.com/joshuasundance-swca/langchain-streamlit-demo/6719ba7c6de5637a09e953c98a52e7dadd869655/langchain-streamlit-demo/app.py',
#   'https://raw.githubusercontent.com/joshuasundance-swca/langchain-streamlit-demo/6719ba7c6de5637a09e953c98a52e7dadd869655/langchain-streamlit-demo/summarize.py',
#   'https://raw.githubusercontent.com/joshuasundance-swca/langchain-streamlit-demo/6719ba7c6de5637a09e953c98a52e7dadd869655/langchain-streamlit-demo/qagen.py'],
#  'saqib772/Prompt-Engineering-LangChain': ['https://raw.githubusercontent.com/saqib772/Prompt-Engineering-LangChain/d12c6f5ebf45fdd7ee5fea312458cd7701e7c19f/Sentiment_prompt.py',
#   'https://raw.githubusercontent.com/saqib772/Prompt-Engineering-LangChain/d12c6f5ebf45fdd7ee5fea312458cd7701e7c19f/plain_text_Generator.py',
#   'https://raw.githubusercontent.com/saqib772/Prompt-Engineering-LangChain/d12c6f5ebf45fdd7ee5fea312458cd7701e7c19f/Summarization_propmt.py',
#   'https://raw.githubusercontent.com/saqib772/Prompt-Engineering-LangChain/d12c6f5ebf45fdd7ee5fea312458cd7701e7c19f/Crop%20Disease%20Diagnosis.py',
#   'https://raw.githubusercontent.com/saqib772/Prompt-Engineering-LangChain/d12c6f5ebf45fdd7ee5fea312458cd7701e7c19f/Customer%20Support.py',
#   'https://raw.githubusercontent.com/saqib772/Prompt-Engineering-LangChain/d12c6f5ebf45fdd7ee5fea312458cd7701e7c19f/Meeting%20Scheduler.py',
#   'https://raw.githubusercontent.com/saqib772/Prompt-Engineering-LangChain/d12c6f5ebf45fdd7ee5fea312458cd7701e7c19f/Patient%20Diagnosis.py',
#   'https://raw.githubusercontent.com/saqib772/Prompt-Engineering-LangChain/d12c6f5ebf45fdd7ee5fea312458cd7701e7c19f/Car%20Maintenance%20Tips.py',
#   'https://raw.githubusercontent.com/saqib772/Prompt-Engineering-LangChain/d12c6f5ebf45fdd7ee5fea312458cd7701e7c19f/Movie%20Recommendation.py',
#   'https://raw.githubusercontent.com/saqib772/Prompt-Engineering-LangChain/d12c6f5ebf45fdd7ee5fea312458cd7701e7c19f/Recipe%20Recommendation.py',
#   'https://raw.githubusercontent.com/saqib772/Prompt-Engineering-LangChain/d12c6f5ebf45fdd7ee5fea312458cd7701e7c19f/Outfit%20Recommendation.py',
#   'https://raw.githubusercontent.com/saqib772/Prompt-Engineering-LangChain/d12c6f5ebf45fdd7ee5fea312458cd7701e7c19f/Product%20Recommendation.py',
#   'https://raw.githubusercontent.com/saqib772/Prompt-Engineering-LangChain/d12c6f5ebf45fdd7ee5fea312458cd7701e7c19f/Campaign%20Idea%20Generation.py',
#   'https://raw.githubusercontent.com/saqib772/Prompt-Engineering-LangChain/d12c6f5ebf45fdd7ee5fea312458cd7701e7c19f/Study%20Plan%20Recommendation.py',
#   'https://raw.githubusercontent.com/saqib772/Prompt-Engineering-LangChain/d12c6f5ebf45fdd7ee5fea312458cd7701e7c19f/Equipment%20Troubleshooting.py',
#   'https://raw.githubusercontent.com/saqib772/Prompt-Engineering-LangChain/d12c6f5ebf45fdd7ee5fea312458cd7701e7c19f/Investment%20Recommendation.py',
#   'https://raw.githubusercontent.com/saqib772/Prompt-Engineering-LangChain/d12c6f5ebf45fdd7ee5fea312458cd7701e7c19f/Travel%20Itinerary%20Planning.py',
#   'https://raw.githubusercontent.com/saqib772/Prompt-Engineering-LangChain/d12c6f5ebf45fdd7ee5fea312458cd7701e7c19f/Training%20Routine%20Recommendation.py',
#   'https://raw.githubusercontent.com/saqib772/Prompt-Engineering-LangChain/d12c6f5ebf45fdd7ee5fea312458cd7701e7c19f/Weapon%20Selection%20Recommendation.py',
#   'https://raw.githubusercontent.com/saqib772/Prompt-Engineering-LangChain/d12c6f5ebf45fdd7ee5fea312458cd7701e7c19f/Personalized%20Recipe%20Recommendation.py'],
#  'cyai/YT2Brief': ['https://raw.githubusercontent.com/cyai/YT2Brief/16f1866cf166efbd42dc7c4e47c59676b7e1aa00/YT2Brief/summarize.py'],
#  'gkamradt/langchain-streamlit-example': ['https://raw.githubusercontent.com/gkamradt/langchain-streamlit-example/685e03f91e6422712ef5ca0f6d261d8835911890/main.py'],
#  'vvhg1/guided-text-generation-with-classifier-free-language-diffusion': ['https://raw.githubusercontent.com/vvhg1/guided-text-generation-with-classifier-free-language-diffusion/7d7c2ab38be5ceed6075c9ea72f3eaafb06d70e3/transformers/src/transformers/commands/add_new_model_like.py'],
#  'petermartens98/LangChain-AutoGPT-YouTube-Script-Generation-Streamlit-App': ['https://raw.githubusercontent.com/petermartens98/LangChain-AutoGPT-YouTube-Script-Generation-Streamlit-App/5e4322fa4a711614b63ed073e4ad70840b429832/YT_Script_Generator/app.py'],
#  'shiyindaxiaojie/eden-aigc-qna': ['https://raw.githubusercontent.com/shiyindaxiaojie/eden-aigc-qna/155f82185052ba68519c5c7a5409cc70e121f73c/example/01_langchain/how_to_use_prompt_template.py',
#   'https://raw.githubusercontent.com/shiyindaxiaojie/eden-aigc-qna/155f82185052ba68519c5c7a5409cc70e121f73c/code/utilities/custom_prompt.py',
#   'https://raw.githubusercontent.com/shiyindaxiaojie/eden-aigc-qna/155f82185052ba68519c5c7a5409cc70e121f73c/code/utilities/llm_helper.py',
#   'https://raw.githubusercontent.com/shiyindaxiaojie/eden-aigc-qna/155f82185052ba68519c5c7a5409cc70e121f73c/example/01_langchain/how_to_use_chains.py'],
#  'algopapi/RetroformAgent': ['https://raw.githubusercontent.com/algopapi/RetroformAgent/e456290f6870dbdc4584a7694b2ff1ce3ecd9a03/prompts.py',
#   'https://raw.githubusercontent.com/algopapi/RetroformAgent/e456290f6870dbdc4584a7694b2ff1ce3ecd9a03/retro.py'],
#  'riccardobl/chat-jme': ['https://raw.githubusercontent.com/riccardobl/chat-jme/4b4e9826659807a2811ada564fa9c6920e13e3bd/Summary.py',
#   'https://raw.githubusercontent.com/riccardobl/chat-jme/4b4e9826659807a2811ada564fa9c6920e13e3bd/bot.py',
#   'https://raw.githubusercontent.com/riccardobl/chat-jme/4b4e9826659807a2811ada564fa9c6920e13e3bd/query/discoursequery.py'],
#  'tddschn/langwhat': ['https://raw.githubusercontent.com/tddschn/langwhat/98c9023b2d898e2aa1934d6568421fb23d13a5dc/langwhat/utils.py'],
#  'OnaZeroN/WebGPT': ['https://raw.githubusercontent.com/OnaZeroN/WebGPT/2f83a7a30a055432fb14e2f14f30bb8746283c7d/web_gpt/web_gpt.py',
#   'https://raw.githubusercontent.com/OnaZeroN/WebGPT/2f83a7a30a055432fb14e2f14f30bb8746283c7d/web_gpt/langchain_helper.py'],
#  'Alexis97/GPT_Reading_Assistant': ['https://raw.githubusercontent.com/Alexis97/GPT_Reading_Assistant/ecc78cd7749f1d223cf225487e1cceac21abb9a8/prompts.py',
#   'https://raw.githubusercontent.com/Alexis97/GPT_Reading_Assistant/ecc78cd7749f1d223cf225487e1cceac21abb9a8/webui.py',
#   'https://raw.githubusercontent.com/Alexis97/GPT_Reading_Assistant/ecc78cd7749f1d223cf225487e1cceac21abb9a8/model.py'],
#  'LeonardoRocca-13/Project_Advertisement': ['https://raw.githubusercontent.com/LeonardoRocca-13/Project_Advertisement/0cc69c967aa25de2ae47fbd00de72cf1444346b5/project/libraries/text_generation.py'],
#  'tomtang110/law_for_chat': ['https://raw.githubusercontent.com/tomtang110/law_for_chat/e72a9a52deeefb2ccc874dc6675f3e72db91a827/langchain-ChatGLM/chains/local_doc_qa.py',
#   'https://raw.githubusercontent.com/tomtang110/law_for_chat/e72a9a52deeefb2ccc874dc6675f3e72db91a827/belle/utils/data/raw_datasets.py',
#   'https://raw.githubusercontent.com/tomtang110/law_for_chat/e72a9a52deeefb2ccc874dc6675f3e72db91a827/langchain-ChatGLM/configs/model_config.py'],
#  'zapier/langchain-nla-util': ['https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/memory/prompt.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/evaluation/qa/eval_prompt.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/chains/qa_with_sources/stuff_prompt.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/chains/qa_with_sources/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/agents/react/wiki_prompt.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/prompts/few_shot_with_templates.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/chains/pal/colored_object_prompt.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/chains/pal/math_prompt.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/prompts/example_selector/ngram_overlap.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/chains/question_answering/map_rerank_prompt.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/chains/natbot/prompt.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/chains/prompt_selector.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/agents/react/textworld_prompt.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/chains/constitutional_ai/prompts.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/prompts/few_shot.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/chains/question_answering/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/prompts/example_selector/length_based.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/tools/sql_database/tool.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/prompts/chat.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/chains/llm_checker/prompt.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/chains/sql_database/base.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/chains/question_answering/__init__.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/example_generator.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/agents/mrkl/base.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/chains/hyde/prompts.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/memory/entity.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/indexes/prompts/entity_summarization.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/chains/graph_qa/base.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/chains/llm_bash/base.py',
#   'https://raw.githubusercontent.com/zapier/langchain-nla-util/df7871f88abb638e05af63deb5d3f2588b99ac65/langchain/agents/self_ask_with_search/base.py'],
#  'tddschn/langchain-utils': ['https://raw.githubusercontent.com/tddschn/langchain-utils/b6eb01f1105bc230b495712630156c4ad8dfe635/langchain_utils/utils.py',
#   'https://raw.githubusercontent.com/tddschn/langchain-utils/b6eb01f1105bc230b495712630156c4ad8dfe635/scripts/gen_readme.py',
#   'https://raw.githubusercontent.com/tddschn/langchain-utils/b6eb01f1105bc230b495712630156c4ad8dfe635/langchain_utils/job_search/lcu_referral_statement.py',
#   'https://raw.githubusercontent.com/tddschn/langchain-utils/b6eb01f1105bc230b495712630156c4ad8dfe635/langchain_utils/config.py'],
#  'gabrielcassimiro17/async-langchain': ['https://raw.githubusercontent.com/gabrielcassimiro17/async-langchain/d5fd3de93c1226491e6636e416b197d777e9744a/async_chain.py',
#   'https://raw.githubusercontent.com/gabrielcassimiro17/async-langchain/d5fd3de93c1226491e6636e416b197d777e9744a/sequential_chain.py'],
#  'nestordemeure/GPTranslate': ['https://raw.githubusercontent.com/nestordemeure/GPTranslate/57cf9c5d48982771e3218a51a602b7e0d1817fe7/GPTranslate/translation/translator.py'],
#  'llm-ai-dev/langchain-wiki': ['https://raw.githubusercontent.com/llm-ai-dev/langchain-wiki/1dc75d26f054084c003c6fa3e614199e21ac8745/app/main.py'],
#  'mattflo/WeatherChatAI': ['https://raw.githubusercontent.com/mattflo/WeatherChatAI/94cf92d1cd880f8502211d01c53dbf4c914a8d9a/weather_chat_ai/location_chain.py',
#   'https://raw.githubusercontent.com/mattflo/WeatherChatAI/94cf92d1cd880f8502211d01c53dbf4c914a8d9a/weather_chat_ai/reply_chain.py'],
#  'smaameri/private-llm': ['https://raw.githubusercontent.com/smaameri/private-llm/b813452ae0f327c757cceddff27033219aaa04da/cloud-llm.py',
#   'https://raw.githubusercontent.com/smaameri/private-llm/b813452ae0f327c757cceddff27033219aaa04da/local-llm-chain.py'],
#  'Coding-Crashkurse/LangChain-On-Azure': ['https://raw.githubusercontent.com/Coding-Crashkurse/LangChain-On-Azure/c8a8ecf1b5efe26ccc3589794b30646018a59bbb/application.py'],
#  'FredGoo/langchain-chinese-chat-models': ['https://raw.githubusercontent.com/FredGoo/langchain-chinese-chat-models/e44e3dd4c0e01e2fa03d15e7c0547df40cc73c8d/test/openai_test.py',
#   'https://raw.githubusercontent.com/FredGoo/langchain-chinese-chat-models/e44e3dd4c0e01e2fa03d15e7c0547df40cc73c8d/test/zhipuai_test.py',
#   'https://raw.githubusercontent.com/FredGoo/langchain-chinese-chat-models/e44e3dd4c0e01e2fa03d15e7c0547df40cc73c8d/test/xfyun_test.py'],
#  'rexsimiloluwah/streamlit-llm-apps': ['https://raw.githubusercontent.com/rexsimiloluwah/streamlit-llm-apps/a989e6d313d756b38232f6b954a8309a50631071/src/utils/poem_generator.py',
#   'https://raw.githubusercontent.com/rexsimiloluwah/streamlit-llm-apps/a989e6d313d756b38232f6b954a8309a50631071/src/utils/qa.py'],
#  'oresttokovenko/gpt-anki': ['https://raw.githubusercontent.com/oresttokovenko/gpt-anki/c88c6c2a6065aa5656052a5eb98fb8968676eeb5/src/generate_flashcards.py'],
#  'waseemhnyc/langchain-huggingface-template': ['https://raw.githubusercontent.com/waseemhnyc/langchain-huggingface-template/2116353753c553538522e274e63c564dd6fc5d11/main.py'],
#  'zitterbewegung/saturday': ['https://raw.githubusercontent.com/zitterbewegung/saturday/beb79508f4a49816741c7bbb04f06af3673c457a/inference.py',
#   'https://raw.githubusercontent.com/zitterbewegung/saturday/beb79508f4a49816741c7bbb04f06af3673c457a/test.py'],
#  'abhishek-ch/Kubectl-GPT': ['https://raw.githubusercontent.com/abhishek-ch/Kubectl-GPT/fcab549669ed045936ad1f7a69302e60ee74de6f/kgpt/agent.py'],
#  'ibizabroker/slack-hr-gpt': ['https://raw.githubusercontent.com/ibizabroker/slack-hr-gpt/571c598454547d46412bd7ae6e6d9ad993096e11/llm/chain.py',
#   'https://raw.githubusercontent.com/ibizabroker/slack-hr-gpt/571c598454547d46412bd7ae6e6d9ad993096e11/llm/templates.py'],
#  'CognitiveLabs/GPT-auto-webscraping': ['https://raw.githubusercontent.com/CognitiveLabs/GPT-auto-webscraping/596bda610c0d9ea24d011ac0cd4eef00dafe494d/chains/code_generator/templates.py',
#   'https://raw.githubusercontent.com/CognitiveLabs/GPT-auto-webscraping/596bda610c0d9ea24d011ac0cd4eef00dafe494d/chains/output_format/templates.py',
#   'https://raw.githubusercontent.com/CognitiveLabs/GPT-auto-webscraping/596bda610c0d9ea24d011ac0cd4eef00dafe494d/chains/code_generator/base.py',
#   'https://raw.githubusercontent.com/CognitiveLabs/GPT-auto-webscraping/596bda610c0d9ea24d011ac0cd4eef00dafe494d/AssistantService.py',
#   'https://raw.githubusercontent.com/CognitiveLabs/GPT-auto-webscraping/596bda610c0d9ea24d011ac0cd4eef00dafe494d/chains/output_format/base.py'],
#  'hammer-mt/thumb': ['https://raw.githubusercontent.com/hammer-mt/thumb/10dccfd2890aa61ef978f2fedc568d1ae18398ac/src/thumb/llm.py',
#   'https://raw.githubusercontent.com/hammer-mt/thumb/10dccfd2890aa61ef978f2fedc568d1ae18398ac/src/thumb/ape.py'],
#  'aishwaryaprabhat/BigBertha': ['https://raw.githubusercontent.com/aishwaryaprabhat/BigBertha/5285e8330110d49dbdb7d31619397079a46b9a0a/demo-container/chatbot/app.py',
#   'https://raw.githubusercontent.com/aishwaryaprabhat/BigBertha/5285e8330110d49dbdb7d31619397079a46b9a0a/demo-container/requirements.txt'],
#  'fvaleye/delta-buddy': ['https://raw.githubusercontent.com/fvaleye/delta-buddy/5c3e4322cc78233c820e08362e56084ec6c2ce7f/app/chatbot.py'],
#  'Madhav-MKNC/admin-portal': ['https://raw.githubusercontent.com/Madhav-MKNC/admin-portal/c962d07f53270281aa4e1ca4dff9e2711add3597/chatbot.py',
#   'https://raw.githubusercontent.com/Madhav-MKNC/admin-portal/c962d07f53270281aa4e1ca4dff9e2711add3597/app.py',
#   'https://raw.githubusercontent.com/Madhav-MKNC/admin-portal/c962d07f53270281aa4e1ca4dff9e2711add3597/test/memory.py',
#   'https://raw.githubusercontent.com/Madhav-MKNC/admin-portal/c962d07f53270281aa4e1ca4dff9e2711add3597/test/chatbot_test.py'],
#  'craigsdennis/llm-trip-saver': ['https://raw.githubusercontent.com/craigsdennis/llm-trip-saver/19c35b8ca9d3fc2765b618cb6254d997f81c5f59/company-generator.py',
#   'https://raw.githubusercontent.com/craigsdennis/llm-trip-saver/19c35b8ca9d3fc2765b618cb6254d997f81c5f59/requirements.txt'],
#  'EswarDivi/DocuConverse': ['https://raw.githubusercontent.com/EswarDivi/DocuConverse/042996e08d7e9bbc6ccc6025674792fa5036a034/Talkwithpdf.py'],
#  'keshy/Langchain_model_router': ['https://raw.githubusercontent.com/keshy/Langchain_model_router/ec7c97d15a8475d92b070b14490ca7c4920990af/prompt_config.py',
#   'https://raw.githubusercontent.com/keshy/Langchain_model_router/ec7c97d15a8475d92b070b14490ca7c4920990af/main.py'],
#  'Vargha-Kh/Langchain_LLM': ['https://raw.githubusercontent.com/Vargha-Kh/Langchain_LLM/0f5383e08908e014d967711b3f5df673a67f3830/langchain_llm.py'],
#  'TOBB-ETU-CS-Community/TOBB-GPT': ['https://raw.githubusercontent.com/TOBB-ETU-CS-Community/TOBB-GPT/03a0b3a48b7503ab42a88589d2afc13e1de01315/tobb_gpt/app.py'],
#  'yuekaizhang/minutes': ['https://raw.githubusercontent.com/yuekaizhang/minutes/c589b4fa0dcd243953849fd7c11f17eab570d9cf/pipeline.py',
#   'https://raw.githubusercontent.com/yuekaizhang/minutes/c589b4fa0dcd243953849fd7c11f17eab570d9cf/summarize.py'],
#  'shpetimhaxhiu/agi-taskgenius-gpt': ['https://raw.githubusercontent.com/shpetimhaxhiu/agi-taskgenius-gpt/0dd25c481cb91dab04da91996c822b8bc1fc46a1/app.py'],
#  '0ptim/JellyChat': ['https://raw.githubusercontent.com/0ptim/JellyChat/7ced8f06a65644b94503c3ad501ea50902c40ad1/backend/tools/wiki_qa.py',
# ...
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/interface/prompts/base.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/template/frontend_node/chains.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/interface/agents/custom.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/api/utils.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/interface/types.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/interface/custom/custom_component.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/components/agents/OpenAIConversationalAgent.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/api/v1/schemas.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/processing/process.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/interface/initialize/loading.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/api/v1/base.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/components/chains/PromptRunner.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/interface/initialize/utils.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/template/frontend_node/__init__.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/interface/prompts/custom.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/utils/payload.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/graph/vertex/types.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/field_typing/constants.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/api/v1/validate.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/custom/customs.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/field_typing/__init__.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/interface/custom/constants.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/graph/vertex/base.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/graph/edge/base.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/interface/chains/custom.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/src/backend/langflow/interface/importing/utils.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/tests/test_prompts_template.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/tests/test_endpoints.py',
#   'https://raw.githubusercontent.com/logspace-ai/langflow/1df4f69b23fbb6cdc42ffb44902ebdd3beaa181a/tests/test_chains_template.py'],
#  'chatchat-space/Langchain-Chatchat': ['https://raw.githubusercontent.com/chatchat-space/Langchain-Chatchat/349adbdfa7ae511a8713bde66cfd71bac1195a7b/server/agent/custom_template.py',
#   'https://raw.githubusercontent.com/chatchat-space/Langchain-Chatchat/349adbdfa7ae511a8713bde66cfd71bac1195a7b/server/utils.py',
#   'https://raw.githubusercontent.com/chatchat-space/Langchain-Chatchat/349adbdfa7ae511a8713bde66cfd71bac1195a7b/server/agent/tools/weather.py',
#   'https://raw.githubusercontent.com/chatchat-space/Langchain-Chatchat/349adbdfa7ae511a8713bde66cfd71bac1195a7b/server/chat/agent_chat.py',
#   'https://raw.githubusercontent.com/chatchat-space/Langchain-Chatchat/349adbdfa7ae511a8713bde66cfd71bac1195a7b/server/agent/tools/search_all_knowledge_more.py',
#   'https://raw.githubusercontent.com/chatchat-space/Langchain-Chatchat/349adbdfa7ae511a8713bde66cfd71bac1195a7b/server/chat/chat.py',
#   'https://raw.githubusercontent.com/chatchat-space/Langchain-Chatchat/349adbdfa7ae511a8713bde66cfd71bac1195a7b/server/chat/search_engine_chat.py',
#   'https://raw.githubusercontent.com/chatchat-space/Langchain-Chatchat/349adbdfa7ae511a8713bde66cfd71bac1195a7b/server/model_workers/zhipu.py',
#   'https://raw.githubusercontent.com/chatchat-space/Langchain-Chatchat/349adbdfa7ae511a8713bde66cfd71bac1195a7b/webui_pages/dialogue/dialogue.py',
#   'https://raw.githubusercontent.com/chatchat-space/Langchain-Chatchat/349adbdfa7ae511a8713bde66cfd71bac1195a7b/chains/llmchain_with_history.py',
#   'https://raw.githubusercontent.com/chatchat-space/Langchain-Chatchat/349adbdfa7ae511a8713bde66cfd71bac1195a7b/server/chat/knowledge_base_chat.py',
#   'https://raw.githubusercontent.com/chatchat-space/Langchain-Chatchat/349adbdfa7ae511a8713bde66cfd71bac1195a7b/server/chat/utils.py',
#   'https://raw.githubusercontent.com/chatchat-space/Langchain-Chatchat/349adbdfa7ae511a8713bde66cfd71bac1195a7b/server/agent/tools/calculate.py',
#   'https://raw.githubusercontent.com/chatchat-space/Langchain-Chatchat/349adbdfa7ae511a8713bde66cfd71bac1195a7b/server/agent/tools/search_all_knowledge_once.py',
#   'https://raw.githubusercontent.com/chatchat-space/Langchain-Chatchat/349adbdfa7ae511a8713bde66cfd71bac1195a7b/server/agent/tools/translator.py',
#   'https://raw.githubusercontent.com/chatchat-space/Langchain-Chatchat/349adbdfa7ae511a8713bde66cfd71bac1195a7b/tests/agent/test_agent_function.py'],
#  'run-llama/llama_index': ['https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/llm_predictor/vellum/prompt_registry.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/indices/prompt_helper.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/indices/vector_store/retrievers/auto_retriever/prompts.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/prompts/prompt_utils.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/program/llm_prompt_program.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/prompts/base.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/prompts/chat_prompts.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/indices/postprocessor/node.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/llm_predictor/vellum/predictor.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/prompts/guidance_utils.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/query_engine/sql_vector_query_engine.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/question_gen/openai_generator.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/llm_predictor/structured.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/indices/postprocessor/llm_rerank.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/prompts/default_prompt_selectors.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/selectors/llm_selectors.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/evaluation/correctness.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/response_synthesizers/factory.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/llms/huggingface.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/experimental/classifier/utils.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/program/llm_program.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/indices/struct_store/sql_query.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/evaluation/guideline.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/program/openai_program.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/indices/keyword_table/retrievers.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/evaluation/pairwise.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/indices/struct_store/sql_retriever.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/program/guidance_program.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/program/predefined/evaporate/extractor.py',
#   'https://raw.githubusercontent.com/run-llama/llama_index/aa00a0071f9c7918df5a8fc294e921da7a29fda2/llama_index/indices/vector_store/retrievers/auto_retriever/auto_retriever.py'],
#  'langchain-ai/langchain': ['https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/schema/prompt_template.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/chains/query_constructor/prompt.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/evaluation/qa/eval_prompt.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/chains/router/multi_prompt.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/evaluation/agents/trajectory_eval_prompt.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/chains/qa_with_sources/stuff_prompt.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/chains/qa_with_sources/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/templates/elastic-query-generator/elastic_query_generator/prompts.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/agents/react/wiki_prompt.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/chains/question_answering/map_rerank_prompt.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/chains/prompt_selector.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/chains/router/multi_prompt_prompt.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/chains/router/multi_retrieval_prompt.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/memory/prompt.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/prompts/few_shot_with_templates.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/experimental/langchain_experimental/pal_chain/colored_object_prompt.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/agents/react/textworld_prompt.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/prompts/base.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/experimental/langchain_experimental/sql/vector_sql.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/experimental/langchain_experimental/pal_chain/math_prompt.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/prompts/few_shot.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/prompts/chat.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/chains/question_answering/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/indexes/prompts/entity_extraction.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/indexes/prompts/entity_summarization.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/agents/agent_toolkits/openapi/planner_prompt.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/experimental/langchain_experimental/prompts/load.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/prompts/example_selector/ngram_overlap.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/libs/langchain/langchain/prompts/example_selector/length_based.py',
#   'https://raw.githubusercontent.com/langchain-ai/langchain/1f27104626fc71a5199df965011810426dd2eede/templates/neo4j-cypher-ft/neo4j_cypher_ft/chain.py']}
