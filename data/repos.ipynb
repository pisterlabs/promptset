# %% [markdown]
# # Objectives
#
# 1. **Search for candidate repos** (containing prompts in .py/.txt files) using:
#     - LangChain
#     - Guidance (by Microsoft)
#     - LlamaIndex
# 2. **Find Prompts**:
#     - 2.1. Filter down via dirs and files
#         - Look at dirs for 'template' or 'prompt' folders (or files)
#     - 2.2. Filter down via code search:
#         - imports some library like openai, hugginface, etc.
#         - (are they in files? Strings?
#         - How many use variables?
#         - Do they concat, use f-strings, use format? Etc.)
#
# <br />
#
# **Possible Next Steps**:
# - Skim through a random sample set of files manually
# - Run professor's **sslim check tool** on them
#     - Professor's tool: https://github.com/kpister/sllim (semantic analysis to detect errors in prompt files)

# %% [markdown]
# ## 📚 **Candidate Repos**

# %%
import requests, json
from pprint import pprint

def fetch_data(query="langchain+OR+GUIDANCE+OR+LlamaIndex", sort="stars", order="asc", per_page=100, language="python"):
    """
    # GitHub API URL for searching repositories
    # DOCS: https://docs.github.com/en/rest/search/search?apiVersion=2022-11-28#search-repositories

    # Params Default
    query = "langchain+OR+GUIDANCE+OR+LlamaIndex"
    sort = "stars"
    order = "asc"
    per_page = 100  # Max 100
    language = "python"

    Returns a results dict with the following structure:
    {
        total_count: int,
        items: [{repo1_info}, {repo2_info}, ...]
    }
    """
    # Setting up result dict and file
    result = {"total_count": 0, "items": []}
    
    # NOTE: Only the first 1000 search results are available through this API
    print("Fetching all 10 pages (assuming there're >= 1000 results)")
    for page in range(1, 11):
        url = f"https://api.github.com/search/repositories?q={query}+language:{language}&sort={sort}&order={order}&per_page={per_page}&page={page}"
        # Make the API request and get the JSON response
        response = requests.get(url)
        data = response.json()

        # Check if the request was successful
        if response.status_code != 200:
            raise Exception(data.get("message", "Unknown error"))

        # Check if the API returned an error
        if "message" in data:
            raise Exception(data["message"])
        
        # Add the results to the result list and file
        result["items"].extend(data["items"])
        print(f"Page {page} done")

    # Add the total count to the result
    result["total_count"] = data["total_count"]

    return result

# WARNING: AVOID EXCEEDING THE API rate limit (10 times per minute).
# More Details in the DOCS.
# STORING RESULT (Uncomment when needed)
##################################################
# repos = fetch_data()
# with open("repos.json", "w") as file:
#     json.dump(repos, file, indent=4)
# pprint(repos)

# %% [markdown]
# ## 🔎 **Find Prompts**

# %%
from utils import get_api_key_github  # custom function for privacy. Get your own API key from
import time

def search_repo(repo_name, username="DJPAUL2001", api_key=get_api_key_github()):
    """
    Searches a repo for promp or template file. HELPER FUNCTION for search_all_repos()
    Github API URL: https://docs.github.com/en/rest/search/search?apiVersion=2022-11-28#search-code

    When searching for code, you can get text match metadata for the file content and file path fields when you pass 
    the text-match media type. For more details about how to receive highlighted search results

    Note: The "Search code" endpoint requires you to authenticate and limits you to 10 requests per minute

    Returns a list of files. e.g. [{file1_info}, {file2_info}, ...]
    """
    url = f"https://api.github.com/search/code?q=prompt+OR+template+in:file+language:text+OR+language:python+repo:{repo_name}"
    response = requests.get(url, auth=(username, api_key))
    data = response.json()

    # Check if the request was successful
    if response.status_code != 200:
        raise Exception(data.get("message", "Unknown error"))
    
    # Check if the API returned an error
    if "message" in data:
        raise Exception(data["message"])
    
    return data["items"]

def search_all_repos(repos, username="DJPAUL2001", api_key=get_api_key_github()):
    """
    Running search_repo() on all candidate repos in repos.json. Approx runtime: > 1 hr 40 mins (took 115 mins)

    Returns a dict with the following structure:
    {
        repo_name1: [{file1_info}, {file2_info}, ...],
        repo_name2: [{file1_info}, {file2_info}, ...],
        ...
    }
    """
    repos_prompts = {}
    for repo in repos["items"]:
        repo_name = repo["full_name"]
        try:
            repos_prompts[repo_name] = search_repo(repo_name, username, api_key)
        except Exception as e:
            print(f"Error: {e}")
            # Assuming the exception is due to rate limit, wait for 1 minute and try again
            time.sleep(60)
            repos_prompts[repo_name] = search_repo(repo_name, username, api_key)

    return repos_prompts

# STORING RESULT (Uncomment when needed)
##################################################
# # Loading repos.json to memory
# with open("repos.json", "r") as file:
#     repos = json.load(file)

# repos_prompts = search_all_repos(repos)
# with open("repos_prompts.json", "w") as file:
#     json.dump(repos_prompts, file, indent=4)
# pprint(repos_prompts)

# %% [markdown]
# 🗨️ Number of Repos with Prompts

# %%
# Loading prompts search results from all repos
with open("repos_prompts.json", "r") as file:
    repos_prompts = json.load(file)

# Counting number of repos with prompt/template search results
count = 0
for repo_name, files in repos_prompts.items():
    if len(files) > 0:
        count += 1

print(f"Number of repos with prompts: {count} out of {len(repos_prompts)}")
# Out:
# Number of repos with prompts: 101 out of 1000

# %% [markdown]
# 📂 Grabbing and Storing all raw file URLs in one place

# %%
def get_rawFileURL():
    """
    NOTE: To get raw file content: 
    1. grab the html_url of a code_search item
    2. remove blob/
    3. replace with github.com with raw.githubusercontent.com

    e.g.
    res = requests.get('https://raw.githubusercontent.com/langchain-ai/langchain/98aff29fbda6bcb99ea6af0cfd1532954b504bdc/libs/langchain/langchain/schema/prompt_template.py')
    print(res.text)

    
    Returns a dict with the following structure (Note: Only contains repos with prompt/template files):
    {
        repo_name1: [file_raw_url1, file_raw_url2, ...],
        repo_name2: [file_raw_url1, file_raw_url2, ...],
        ...
    }
    """
    repo_to_fileURL = {}
    for repo, files in repos_prompts.items():
        for file in files:
            file_raw_url = file["html_url"].replace("blob/", "").replace("github.com", "raw.githubusercontent.com")
            repo_to_fileURL[repo] = repo_to_fileURL.get(repo, []) + [file_raw_url]

    # STORING RESULT
    with open("repo_to_rawFileURL.json", "w") as file:
        json.dump(repo_to_fileURL, file, indent=4)

    return repo_to_fileURL

get_rawFileURL()
# Out:
# {'PankajBhatia06/LangChainBot': ['https://raw.githubusercontent.com/PankajBhatia06/LangChainBot/395ab40a0c975f55e14fef6ae1b23c4079c19f20/app.py'],
#  'Data-drone/langchain_tests': ['https://raw.githubusercontent.com/Data-drone/langchain_tests/dfcbf08437a668ff5ddbb76f26e838a39b7fe9ec/app/doc_chatbot.py'],
#  'HardyZ1906/evadb-llamaindex-bot': ['https://raw.githubusercontent.com/HardyZ1906/evadb-llamaindex-bot/337f77df4be8eede78a61e961519200f27676f4d/helper_bot.py'],
#  'sharmaD91/LlamaIndex-Tutorial': ['https://raw.githubusercontent.com/sharmaD91/LlamaIndex-Tutorial/a44e86949dad1c5403fd2566eb9ed2dbcb68afa9/app.py'],
#  'yudai1204/LlamaIndex-LineBot': ['https://raw.githubusercontent.com/yudai1204/LlamaIndex-LineBot/c6813479ada813bff8b351e148d24d2ff68bd0ab/app.py'],
#  'Krishnendumondal/Langchain': ['https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/chains/query_constructor/prompt.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/evaluation/qa/eval_prompt.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/chains/router/multi_prompt.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/evaluation/agents/trajectory_eval_prompt.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/evaluation/run_evaluators/criteria_prompt.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/chains/qa_with_sources/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/chains/prompt_selector.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/chains/question_answering/map_rerank_prompt.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/chains/router/multi_prompt_prompt.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/chains/router/multi_retrieval_prompt.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/chains/pal/math_prompt.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/chains/question_answering/stuff_prompt.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/agents/react/textworld_prompt.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/chains/natbot/prompt.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/prompts/loading.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/chains/question_answering/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/chains/pal/colored_object_prompt.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/prompts/few_shot_with_templates.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/chains/hyde/prompts.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/agents/agent_toolkits/openapi/planner_prompt.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/llms/aviary.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/agents/chat/base.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/tools/sql_database/tool.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/memory/entity.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/chains/llm_checker/prompt.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/chains/openai_functions/openapi.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/agents/conversational_chat/base.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/evaluation/qa/generate_prompt.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/agents/openai_functions_agent/base.py',
#   'https://raw.githubusercontent.com/Krishnendumondal/Langchain/ba622764cb7ccf4667878289f959857348ef8c19/langchain/agents/self_ask_with_search/prompt.py'],
#  'sunwupark/LLM_Practice': ['https://raw.githubusercontent.com/sunwupark/LLM_Practice/93c2791a84eba023a77da8c56676e10d203d4b96/ice_breaker.py'],
#  'harsha89vyas/backendapp': ['https://raw.githubusercontent.com/harsha89vyas/backendapp/52fe950f7c54a5b0b298032fc571509ddb5e7486/util/process.py',
#   'https://raw.githubusercontent.com/harsha89vyas/backendapp/52fe950f7c54a5b0b298032fc571509ddb5e7486/main.py'],
#  'ssbuild/gpt_chain': ['https://raw.githubusercontent.com/ssbuild/gpt_agent/1a024d6c875dbfbab0598c6197eea5d937facfd9/serving/chat.py',
#   'https://raw.githubusercontent.com/ssbuild/gpt_agent/1a024d6c875dbfbab0598c6197eea5d937facfd9/serving/utils.py'],
#  'kajarenc/streamlit-guidance': ['https://raw.githubusercontent.com/kajarenc/streamlit-guidance/b715ac9cedf7fca6e7f5833043b581c70a5bfad4/app.py'],
#  'archanray/langchainExploration': ['https://raw.githubusercontent.com/archanray/langchainExploration/3890dbbf4d539174fdb93dd051f9e80b652f9780/promptEngineering.py',
#   'https://raw.githubusercontent.com/archanray/langchainExploration/3890dbbf4d539174fdb93dd051f9e80b652f9780/fewShotPrompts.py',
#   'https://raw.githubusercontent.com/archanray/langchainExploration/3890dbbf4d539174fdb93dd051f9e80b652f9780/introCode.py'],
#  'ZouZou/LangchainDocuments': ['https://raw.githubusercontent.com/ZouZou/LangchainDocuments/ee1977c85091dbaba01902943475ef57efb4cc7c/SqlDb/ask_db_nisr.py',
#   'https://raw.githubusercontent.com/ZouZou/LangchainDocuments/ee1977c85091dbaba01902943475ef57efb4cc7c/Office365/email_summarizer.py',
#   'https://raw.githubusercontent.com/ZouZou/LangchainDocuments/ee1977c85091dbaba01902943475ef57efb4cc7c/multiplepdfs.py',
#   'https://raw.githubusercontent.com/ZouZou/LangchainDocuments/ee1977c85091dbaba01902943475ef57efb4cc7c/Office365/email_composer.py',
#   'https://raw.githubusercontent.com/ZouZou/LangchainDocuments/ee1977c85091dbaba01902943475ef57efb4cc7c/Conversation/utilz.py',
#   'https://raw.githubusercontent.com/ZouZou/LangchainDocuments/ee1977c85091dbaba01902943475ef57efb4cc7c/Office365/load_offline_mails.py'],
#  'Claudio9701/langchainApp': ['https://raw.githubusercontent.com/Claudio9701/langchainApp/0e5c77a15bce4bf839c8dd8c49f616c2e07a8d86/main/views.py'],
#  'marcschauer29/langchain1': ['https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/chains/query_constructor/prompt.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/evaluation/qa/eval_prompt.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/chains/router/multi_prompt.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/evaluation/agents/trajectory_eval_prompt.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/chains/qa_with_sources/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/chains/prompt_selector.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/chains/question_answering/map_rerank_prompt.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/chains/router/multi_prompt_prompt.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/chains/router/multi_retrieval_prompt.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/chains/pal/math_prompt.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/chains/question_answering/stuff_prompt.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/agents/react/textworld_prompt.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/chains/natbot/prompt.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/prompts/loading.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/prompts/few_shot_with_templates.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/chains/question_answering/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/evaluation/qa/generate_prompt.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/chains/pal/colored_object_prompt.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/chains/hyde/prompts.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/prompts/chat.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/llms/databricks.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/chains/retrieval_qa/base.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/chains/combine_documents/base.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/agents/agent_toolkits/openapi/planner.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/chains/api/base.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/chains/flare/base.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/prompts/example_selector/length_based.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/chains/graph_qa/base.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/chains/graph_qa/cypher.py',
#   'https://raw.githubusercontent.com/marcschauer29/langchain1/470b2822a3c9c0def3a443a08a5b05105f9dc870/langchain/chains/router/llm_router.py'],
#  'it21011870/langchainAPI': ['https://raw.githubusercontent.com/it21011870/langchainAPI/e51b2e67d99143713ce138aae106bf1c17266fd4/main.py',
#   'https://raw.githubusercontent.com/it21011870/langchainAPI/e51b2e67d99143713ce138aae106bf1c17266fd4/api/main.py'],
#  'congltk1234/LangchainStreamlit': ['https://raw.githubusercontent.com/congltk1234/LangchainStreamlit/2e0137a785ea088dbb6b61dc0ce52019af15e47b/app.py'],
#  'Suchun-sv/LangchainCypher': ['https://raw.githubusercontent.com/Suchun-sv/LangchainCypher/d3ee2490598c7526b21ee3f6ef1e3bc2ed90f2e5/CypherChain/custom_chain_v1.py'],
#  'Harleyzheng/langchain': ['https://raw.githubusercontent.com/Harleyzheng/langchain/03d9f126f755c9594c518cd769eae90045aaf08a/interface.py',
#   'https://raw.githubusercontent.com/Harleyzheng/langchain/03d9f126f755c9594c518cd769eae90045aaf08a/runnable.py',
#   'https://raw.githubusercontent.com/Harleyzheng/langchain/03d9f126f755c9594c518cd769eae90045aaf08a/function.py'],
#  'CodePrometheus/Starry-Ai': ['https://raw.githubusercontent.com/CodePrometheus/Starry-Ai/091274e55ae8f0342b88835991338bbe7eb1fccf/langchain_learning/examples/langchain_bot/bot.py',
#   'https://raw.githubusercontent.com/CodePrometheus/Starry-Ai/091274e55ae8f0342b88835991338bbe7eb1fccf/langchain_learning/3_LLMChain.py',
#   'https://raw.githubusercontent.com/CodePrometheus/Starry-Ai/091274e55ae8f0342b88835991338bbe7eb1fccf/langchain_learning/1_ChatModel.py',
#   'https://raw.githubusercontent.com/CodePrometheus/Starry-Ai/091274e55ae8f0342b88835991338bbe7eb1fccf/langchain_learning/3_SQLDatabaseChain_chain.py'],
#  'domteow/langchainPDF': ['https://raw.githubusercontent.com/domteow/langchainPDF/123113dee1c737b15e77f98b19194aa0f1f481fc/pdf_processing_project/pdf_processing_app/views.py'],
#  'Elhassnaoui2001/Chat-with-an-Image': ['https://raw.githubusercontent.com/Elhassnaoui2001/Chat-with-an-Image/2d0269aaceb9ffe3f6104ca0a958c12f9e88aa15/.env/Lib/site-packages/pip/_vendor/rich/console.py'],
#  'ColdCutConnoisseur/LlamaWebApp': ['https://raw.githubusercontent.com/ColdCutConnoisseur/LlamaWebApp/1eba76300676eff80b08a5f421d870b4f6f80bdd/app.py'],
#  'youngjr0527/LangchainforQnA': ['https://raw.githubusercontent.com/youngjr0527/LangchainforQnA/1c3bc80f7dc2dd3fb50f2dc524ef9e31a78c0e39/Integrate_LangChain.py'],
#  'berataltuntash/Langchain': ['https://raw.githubusercontent.com/berataltuntash/Langchain/65231fe5e37b7765c4c15e6bb217d81f862c7df1/Langchain.py',
#   'https://raw.githubusercontent.com/berataltuntash/Langchain/65231fe5e37b7765c4c15e6bb217d81f862c7df1/agents.py'],
#  'rushbgti/langchain': ['https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/chains/query_constructor/prompt.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/evaluation/qa/eval_prompt.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/chains/router/multi_prompt.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/evaluation/agents/trajectory_eval_prompt.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/chains/qa_with_sources/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/chains/prompt_selector.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/chains/question_answering/map_rerank_prompt.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/chains/router/multi_prompt_prompt.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/chains/router/multi_retrieval_prompt.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/chains/pal/math_prompt.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/chains/question_answering/stuff_prompt.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/agents/react/textworld_prompt.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/chains/natbot/prompt.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/prompts/loading.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/prompts/few_shot_with_templates.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/chains/question_answering/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/evaluation/qa/generate_prompt.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/chains/pal/colored_object_prompt.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/prompts/example_selector/length_based.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/chains/summarize/refine_prompts.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/chains/retrieval_qa/base.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/chains/llm_checker/prompt.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/agents/agent_toolkits/openapi/planner.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/agents/self_ask_with_search/prompt.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/chains/mapreduce.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/chains/hyde/prompts.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/llms/openai.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/model_laboratory.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/chains/summarize/__init__.py',
#   'https://raw.githubusercontent.com/rushbgti/langchain/0a591da6db5c76722e349e03692d674e45ba626a/langchain/chains/qa_with_sources/base.py'],
#  'sudharsanmaran/LangChain': ['https://raw.githubusercontent.com/sudharsanmaran/LangChain/8c3d4e3d6ff01a735569c6325c93a62126fcf323/llm_utils/handle_prompts.py'],
#  'kenwaytis/langchain': ['https://raw.githubusercontent.com/kenwaytis/langchain/f97b639ad957fc2e62578e1552dfa32aa2a096e0/Prompt/CustomPromptTemplates.py',
#   'https://raw.githubusercontent.com/kenwaytis/langchain/f97b639ad957fc2e62578e1552dfa32aa2a096e0/glm.py',
#   'https://raw.githubusercontent.com/kenwaytis/langchain/f97b639ad957fc2e62578e1552dfa32aa2a096e0/doc_search_client.py'],
#  'emmalu/langchain': ['https://raw.githubusercontent.com/emmalu/langchain/e779d9e3889b5202034ff1d1f498e25cdae11b3b/app.py'],
#  'ducnguyen-hekate/langchain': ['https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/prompts/prompt.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/evaluation/qa/eval_prompt.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/chains/qa_with_sources/stuff_prompt.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/chains/qa_with_sources/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/chains/question_answering/map_rerank_prompt.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/chains/pal/math_prompt.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/agents/react/textworld_prompt.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/agents/react/wiki_prompt.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/agents/self_ask_with_search/prompt.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/evaluation/qa/generate_prompt.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/example_generator.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/prompts/loading.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/prompts/example_selector/length_based.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/chains/llm.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/evaluation/qa/eval_chain.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/chains/vector_db_qa/prompt.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/chains/conversation/memory.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/agents/react/base.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/prompts/few_shot.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/chains/combine_documents/stuff.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/prompts/few_shot_with_templates.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/chains/llm_math/base.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/chains/summarize/__init__.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/chains/qa_with_sources/base.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/chains/qa_with_sources/refine_prompts.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/agents/self_ask_with_search/base.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/chains/summarize/stuff_prompt.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/chains/question_answering/__init__.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/prompts/base.py',
#   'https://raw.githubusercontent.com/ducnguyen-hekate/langchain/0b6aa6a02439a3d85099228c091950a99446b071/langchain/__init__.py'],
#  'xuanloct4/langchain': ['https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/prompt_templates.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/meta_prompt.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/agents_executors.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/fewshot.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/chatmodels.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/manifest_llms_mll.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/gpt4all.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/document_qa.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/sharedmemory_agent_tools.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/replicate_llm.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/requirements.txt',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/agents_custom.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/baby_agi_with_tools.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/chat-your-data/query_data.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/api_chains.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/llms.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/petal_llm.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/bash_chain.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/cohere_llm.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/human_input_llm.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/hugging_face_local_pipeline.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/voice-assistant.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/hugging_face_hub.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/agents_tool_retrieval.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/gooseai_llm.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/question_answering.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/nlp_toolkit.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/pythonREPL_tool.py',
#   'https://raw.githubusercontent.com/xuanloct4/langchain/66cace6df2f37fcc041494bbaa71a440cb413a0e/chatgpt_clone.py'],
#  'ankittripathi24/Langchain': ['https://raw.githubusercontent.com/ankittripathi24/Langchain/2bb37fa778abb3cbc75cd2c2ba30bba454280144/app.py',
#   'https://raw.githubusercontent.com/ankittripathi24/Langchain/2bb37fa778abb3cbc75cd2c2ba30bba454280144/model_1.py',
#   'https://raw.githubusercontent.com/ankittripathi24/Langchain/2bb37fa778abb3cbc75cd2c2ba30bba454280144/agents/lookup.py'],
#  'sn-2023/Langchain': ['https://raw.githubusercontent.com/sn-2023/Langchain/1ef1e1dc5d263f0aa8a4ecc4c36ba6fc2706153f/main-original.py',
#   'https://raw.githubusercontent.com/sn-2023/Langchain/1ef1e1dc5d263f0aa8a4ecc4c36ba6fc2706153f/pdf_jarvis.py',
#   'https://raw.githubusercontent.com/sn-2023/Langchain/1ef1e1dc5d263f0aa8a4ecc4c36ba6fc2706153f/main.py'],
#  'Dyson1664/Langchain': ['https://raw.githubusercontent.com/Dyson1664/Langchain/adb3701d6fd636d795534d88b87448c362ee7140/main.py'],
#  'joshwa71/LangChain': ['https://raw.githubusercontent.com/joshwa71/LangChain/aed92fe8168f39a77918778d533c536945554ba3/IceBreaker/agents/linkedin_lookup_agent.py',
#   'https://raw.githubusercontent.com/joshwa71/LangChain/aed92fe8168f39a77918778d533c536945554ba3/IceBreaker/ice_breaker.py'],
#  'amansharma7415369/langchain': ['https://raw.githubusercontent.com/amansharma7415369/langchain/d503d8cd723afa930108c618ac206b59a1b401bf/connecting%20to%20openai.py'],
#  'Harshu467/LangChain': ['https://raw.githubusercontent.com/Harshu467/LangChain/0e600a82390cf90f2fec9945213011afedb1fea2/helper.py'],
#  'theSamyak/LangChain': ['https://raw.githubusercontent.com/theSamyak/LangChain/b014ecbadfa88d0a0051ca0386db68ee60f46b85/LangChain/langchain_davinci_003.py'],
#  'apurvak/langchain': ['https://raw.githubusercontent.com/apurvak/langchain/1c560ef8ba8ca8735a6c0f2e9c1180829c578392/main.py',
#   'https://raw.githubusercontent.com/apurvak/langchain/1c560ef8ba8ca8735a6c0f2e9c1180829c578392/SqlQuotronChain.py',
#   'https://raw.githubusercontent.com/apurvak/langchain/1c560ef8ba8ca8735a6c0f2e9c1180829c578392/VisualizationChain.py'],
#  'm2web/langchain': ['https://raw.githubusercontent.com/m2web/langchain/cdd65ce443ff959dff257494a174f33ff5899782/app-spock-prompt.py',
#   'https://raw.githubusercontent.com/m2web/langchain/cdd65ce443ff959dff257494a174f33ff5899782/app.py',
#   'https://raw.githubusercontent.com/m2web/langchain/cdd65ce443ff959dff257494a174f33ff5899782/app-talk-like-a-pirate.py',
#   'https://raw.githubusercontent.com/m2web/langchain/cdd65ce443ff959dff257494a174f33ff5899782/app-chains.py'],
#  'ohrynets/langchain': ['https://raw.githubusercontent.com/ohrynets/langchain/23e16415df3cd31818674021aa0a4204a0c09f70/job_description_analyzer.py',
#   'https://raw.githubusercontent.com/ohrynets/langchain/23e16415df3cd31818674021aa0a4204a0c09f70/langchain_test.py'],
#  'erodrigu/langchain': ['https://raw.githubusercontent.com/erodrigu/langchain/ac810bf04a1453f93d5511421da1cb6e8834c5d2/application/backend/prompts/sample_prompts.py',
#   'https://raw.githubusercontent.com/erodrigu/langchain/ac810bf04a1453f93d5511421da1cb6e8834c5d2/application/backend/main.py',
#   'https://raw.githubusercontent.com/erodrigu/langchain/ac810bf04a1453f93d5511421da1cb6e8834c5d2/deprecated/quickstart_01.py'],
#  'mitchmalvin1/langchain': ['https://raw.githubusercontent.com/mitchmalvin1/langchain/3f453947a5c48fac72df04c0e1c052c59c3af444/src/app.py'],
#  'Himalaypatel75/LangChain': ['https://raw.githubusercontent.com/Himalaypatel75/LangChain/71e0babf89a61b1ae2eed913c4307184b7f32b15/agents/twitter_lookup_agent.py',
#   'https://raw.githubusercontent.com/Himalaypatel75/LangChain/71e0babf89a61b1ae2eed913c4307184b7f32b15/agents/linkedin_lookup_agent.py',
#   'https://raw.githubusercontent.com/Himalaypatel75/LangChain/71e0babf89a61b1ae2eed913c4307184b7f32b15/ice_breaker.py'],
#  'son-n-pham/Langchain': ['https://raw.githubusercontent.com/son-n-pham/Langchain/2832be5b4bbeaddb52e3934c02011e9205731a0c/temp/hello_world_langchain.py',
#   'https://raw.githubusercontent.com/son-n-pham/Langchain/2832be5b4bbeaddb52e3934c02011e9205731a0c/temp/agents/linkedin_lookup_agent.py',
#   'https://raw.githubusercontent.com/son-n-pham/Langchain/2832be5b4bbeaddb52e3934c02011e9205731a0c/temp/ice_breaker_agents.py',
#   'https://raw.githubusercontent.com/son-n-pham/Langchain/2832be5b4bbeaddb52e3934c02011e9205731a0c/ice_breaker.py',
#   'https://raw.githubusercontent.com/son-n-pham/Langchain/2832be5b4bbeaddb52e3934c02011e9205731a0c/temp/ice_breaker_third_parties.py',
#   'https://raw.githubusercontent.com/son-n-pham/Langchain/2832be5b4bbeaddb52e3934c02011e9205731a0c/agents/linkedin_lookup_agent.py'],
#  'makarl/langchain': ['https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/chains/query_constructor/prompt.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/evaluation/qa/eval_prompt.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/chains/router/multi_prompt.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/evaluation/agents/trajectory_eval_prompt.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/evaluation/run_evaluators/criteria_prompt.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/chains/qa_with_sources/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/chains/prompt_selector.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/chains/question_answering/map_rerank_prompt.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/chains/router/multi_prompt_prompt.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/chains/router/multi_retrieval_prompt.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/chains/pal/math_prompt.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/chains/question_answering/stuff_prompt.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/agents/react/textworld_prompt.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/chains/natbot/prompt.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/prompts/loading.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/chains/question_answering/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/evaluation/qa/generate_prompt.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/chains/pal/colored_object_prompt.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/prompts/few_shot_with_templates.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/chains/hyde/prompts.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/chains/qa_with_sources/refine_prompts.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/llms/databricks.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/chains/retrieval_qa/base.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/chains/llm_checker/prompt.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/agents/conversational_chat/base.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/agents/agent_toolkits/sql/base.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/agents/agent.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/agents/self_ask_with_search/prompt.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/chains/pal/base.py',
#   'https://raw.githubusercontent.com/makarl/langchain/e9a4a57fda4876f205212af6a3d058681fde0674/langchain/chains/mapreduce.py'],
#  'Divyansh-ag14/langchain': ['https://raw.githubusercontent.com/Divyansh-ag14/langchain/aa367d8f9491cb5e8d4bc6deeec7d0dcc77e0c08/email_gpt/app.py'],
#  'Divyansh3021/Langchain': ['https://raw.githubusercontent.com/Divyansh3021/Langchain/9a375716f5257131c6591bc2ca21de71bd647eb4/Pet%20Name%20Generator/helper.py',
#   'https://raw.githubusercontent.com/Divyansh3021/Langchain/9a375716f5257131c6591bc2ca21de71bd647eb4/Document%20Analyzer/main.py',
#   'https://raw.githubusercontent.com/Divyansh3021/Langchain/9a375716f5257131c6591bc2ca21de71bd647eb4/Pet%20Name%20Generator/app.py'],
#  'sdpmas/langchain': ['https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/schema/prompt_template.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/chains/query_constructor/prompt.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/evaluation/qa/eval_prompt.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/chains/router/multi_prompt.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/evaluation/agents/trajectory_eval_prompt.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/chains/qa_with_sources/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/chains/prompt_selector.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/chains/question_answering/map_rerank_prompt.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/agents/agent_toolkits/openapi/planner_prompt.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/prompts/few_shot_with_templates.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/chains/pal/math_prompt.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/prompts/example_selector/ngram_overlap.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/prompts/prompt.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/chains/router/multi_retrieval_prompt.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/prompts/loading.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/prompts/few_shot.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/indexes/prompts/entity_extraction.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/indexes/prompts/entity_summarization.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/chains/summarize/stuff_prompt.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/prompts/example_selector/length_based.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/output_parsers/prompts.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/agents/react/wiki_prompt.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/chains/summarize/refine_prompts.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/tools/spark_sql/tool.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/tools/sql_database/tool.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/chains/sql_database/base.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/evaluation/qa/eval_chain.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/chains/natbot/prompt.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/agents/conversational/base.py',
#   'https://raw.githubusercontent.com/sdpmas/langchain/9f0ce5c86557ec2811dfb13375e0e1fda711d00a/langchain/chains/openai_functions/base.py'],
#  'Kds888/Langchain': ['https://raw.githubusercontent.com/Kds888/Langchain/13d3725c767b2581d7ce3dca2ca20cc3c534f4f6/Test/hello.py',
#   'https://raw.githubusercontent.com/Kds888/Langchain/13d3725c767b2581d7ce3dca2ca20cc3c534f4f6/Test/agents/linkedin_agent.py'],
#  'dmh2000/langchain': ['https://raw.githubusercontent.com/dmh2000/langchain/895b40949885c28ef0d7180b1fb0f4a6c0827430/p1/main.py'],
#  'fieryfalcon/LangChain': ['https://raw.githubusercontent.com/fieryfalcon/LangChain/0df3ad4bba4f8f640784a40784693fcd94f8f715/Langchain_Basics/main.py'],
#  'PCSchmidt/Langchain': ['https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/chains/query_constructor/prompt.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/evaluation/qa/eval_prompt.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/chains/router/multi_prompt.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/evaluation/run_evaluators/criteria_prompt.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/evaluation/agents/trajectory_eval_prompt.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/chains/prompt_selector.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/chains/qa_with_sources/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/chains/question_answering/map_rerank_prompt.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/agents/agent_toolkits/openapi/planner_prompt.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/chains/router/multi_retrieval_prompt.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/chains/pal/math_prompt.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/memory/prompt.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/agents/react/textworld_prompt.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/prompt_toolkit/formatted_text/base.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/agents/react/wiki_prompt.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/prompts/loading.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/chains/constitutional_ai/prompts.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/prompt_toolkit/formatted_text/__init__.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/chains/question_answering/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/chains/summarize/stuff_prompt.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/chains/pal/colored_object_prompt.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/chains/router/multi_prompt_prompt.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/prompt_toolkit/shortcuts/progress_bar/formatters.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/prompts/few_shot_with_templates.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/chains/summarize/refine_prompts.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/chains/question_answering/refine_prompts.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/tools/spark_sql/tool.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/prompts/example_selector/length_based.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/chains/openai_functions/openapi.py',
#   'https://raw.githubusercontent.com/PCSchmidt/Langchain/f4c46b17e98210e45054336b1bc14060dad82899/venv/Lib/site-packages/langchain/indexes/prompts/entity_extraction.py'],
#  'ScorpionBytes/LangChain': ['https://raw.githubusercontent.com/ScorpionBytes/LangChain/7ad13cdbdbd45b1348f199419da836bdbcbc02e2/langchain/chains/query_constructor/prompt.py',
#   'https://raw.githubusercontent.com/ScorpionBytes/LangChain/7ad13cdbdbd45b1348f199419da836bdbcbc02e2/langchain/evaluation/qa/eval_prompt.py',
#   'https://raw.githubusercontent.com/ScorpionBytes/LangChain/7ad13cdbdbd45b1348f199419da836bdbcbc02e2/langchain/chains/router/multi_prompt.py',
#   'https://raw.githubusercontent.com/ScorpionBytes/LangChain/7ad13cdbdbd45b1348f199419da836bdbcbc02e2/langchain/evaluation/agents/trajectory_eval_prompt.py',
#   'https://raw.githubusercontent.com/ScorpionBytes/LangChain/7ad13cdbdbd45b1348f199419da836bdbcbc02e2/langchain/evaluation/run_evaluators/criteria_prompt.py',
#   'https://raw.githubusercontent.com/ScorpionBytes/LangChain/7ad13cdbdbd45b1348f199419da836bdbcbc02e2/langchain/chains/qa_with_sources/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/ScorpionBytes/LangChain/7ad13cdbdbd45b1348f199419da836bdbcbc02e2/langchain/chains/prompt_selector.py',
#   'https://raw.githubusercontent.com/ScorpionBytes/LangChain/7ad13cdbdbd45b1348f199419da836bdbcbc02e2/langchain/chains/question_answering/map_rerank_prompt.py',
#   'https://raw.githubusercontent.com/ScorpionBytes/LangChain/7ad13cdbdbd45b1348f199419da836bdbcbc02e2/langchain/chains/router/multi_prompt_prompt.py',
#   'https://raw.githubusercontent.com/ScorpionBytes/LangChain/7ad13cdbdbd45b1348f199419da836bdbcbc02e2/langchain/chains/router/multi_retrieval_prompt.py',
# ...
#   'https://raw.githubusercontent.com/ramsmail/langchaintut/9020124aa620dd3d679219feef22aa7736eed7d5/ice_breaker.py'],
#  'giovannarkive/langchainsearch': ['https://raw.githubusercontent.com/giovannarkive/langchainsearch/53a354f795756b3f4b1651ec926780a5cc2fb7cb/app.py'],
#  'wilfredinni/ice_breaker': ['https://raw.githubusercontent.com/wilfredinni/ice_breaker/be6d4b1b89837e701cec552bd7760aee9d1dc5c2/agents/twitter_lookup_agent.py',
#   'https://raw.githubusercontent.com/wilfredinni/ice_breaker/be6d4b1b89837e701cec552bd7760aee9d1dc5c2/ice_breaker.py',
#   'https://raw.githubusercontent.com/wilfredinni/ice_breaker/be6d4b1b89837e701cec552bd7760aee9d1dc5c2/agents/linkedin_lookup_agent.py'],
#  'D-Sritha-D/Pdf_Chatbot': ['https://raw.githubusercontent.com/D-Sritha-D/Pdf_Chatbot/66595a572e1c5ab8862c0d87b6e38685576e4a00/app.py'],
#  'yshujie/langchain-demo': ['https://raw.githubusercontent.com/yshujie/langchain-demo/19620b513f2e967cff25604a3edc3d1e575ae9cc/src/case/template/few_shot_prompt_template.py',
#   'https://raw.githubusercontent.com/yshujie/langchain-demo/19620b513f2e967cff25604a3edc3d1e575ae9cc/src/case/template/prompt_template.py',
#   'https://raw.githubusercontent.com/yshujie/langchain-demo/19620b513f2e967cff25604a3edc3d1e575ae9cc/src/case/template/prompt_connection_feature_store.py',
#   'https://raw.githubusercontent.com/yshujie/langchain-demo/19620b513f2e967cff25604a3edc3d1e575ae9cc/src/case/template/function_explainer.py',
#   'https://raw.githubusercontent.com/yshujie/langchain-demo/19620b513f2e967cff25604a3edc3d1e575ae9cc/src/case/template/few_shot_examples_for_chat_models.py',
#   'https://raw.githubusercontent.com/yshujie/langchain-demo/19620b513f2e967cff25604a3edc3d1e575ae9cc/src/case/template/generate_name.py',
#   'https://raw.githubusercontent.com/yshujie/langchain-demo/19620b513f2e967cff25604a3edc3d1e575ae9cc/src/case/template/chat.py',
#   'https://raw.githubusercontent.com/yshujie/langchain-demo/19620b513f2e967cff25604a3edc3d1e575ae9cc/src/case/chains/custom_chain.py',
#   'https://raw.githubusercontent.com/yshujie/langchain-demo/19620b513f2e967cff25604a3edc3d1e575ae9cc/src/case/chains/namer.py',
#   'https://raw.githubusercontent.com/yshujie/langchain-demo/19620b513f2e967cff25604a3edc3d1e575ae9cc/src/case/chains/router.py',
#   'https://raw.githubusercontent.com/yshujie/langchain-demo/19620b513f2e967cff25604a3edc3d1e575ae9cc/src/demo/youtube_bot.py',
#   'https://raw.githubusercontent.com/yshujie/langchain-demo/19620b513f2e967cff25604a3edc3d1e575ae9cc/src/case/chains/film_critic.py',
#   'https://raw.githubusercontent.com/yshujie/langchain-demo/19620b513f2e967cff25604a3edc3d1e575ae9cc/src/demo/fetch_web.py',
#   'https://raw.githubusercontent.com/yshujie/langchain-demo/19620b513f2e967cff25604a3edc3d1e575ae9cc/src/demo/json_outputer.py',
#   'https://raw.githubusercontent.com/yshujie/langchain-demo/19620b513f2e967cff25604a3edc3d1e575ae9cc/src/case/chains/anamer.py',
#   'https://raw.githubusercontent.com/yshujie/langchain-demo/19620b513f2e967cff25604a3edc3d1e575ae9cc/src/demo/local_cuisine_recipe_searcher.py'],
#  'koonn/langchain_sisha': ['https://raw.githubusercontent.com/koonn/langchain_sisha/5014ea96a56eb207e7699cd517092a2c5ccc6138/main.py'],
#  'os1ma/langchain-practice': ['https://raw.githubusercontent.com/os1ma/langchain-practice/72bff99ef1dca42a76aedb96477d47a3a5155abd/langchain_practice/router.py',
#   'https://raw.githubusercontent.com/os1ma/langchain-practice/72bff99ef1dca42a76aedb96477d47a3a5155abd/langchain_practice/memory_in_sequential_chains.py',
#   'https://raw.githubusercontent.com/os1ma/langchain-practice/72bff99ef1dca42a76aedb96477d47a3a5155abd/langchain_practice/retry_parser.py',
#   'https://raw.githubusercontent.com/os1ma/langchain-practice/72bff99ef1dca42a76aedb96477d47a3a5155abd/langchain_practice/multi_query_retriever.py',
#   'https://raw.githubusercontent.com/os1ma/langchain-practice/72bff99ef1dca42a76aedb96477d47a3a5155abd/langchain_practice/extraction.py'],
#  'pooyad359/langchain-experiments': ['https://raw.githubusercontent.com/pooyad359/langchain-experiments/b65c8967b6ec9374061752031802cf34aaa88c4b/app.py',
#   'https://raw.githubusercontent.com/pooyad359/langchain-experiments/b65c8967b6ec9374061752031802cf34aaa88c4b/summarize.py',
#   'https://raw.githubusercontent.com/pooyad359/langchain-experiments/b65c8967b6ec9374061752031802cf34aaa88c4b/chat.py',
#   'https://raw.githubusercontent.com/pooyad359/langchain-experiments/b65c8967b6ec9374061752031802cf34aaa88c4b/doc-qa.py'],
#  'javovelez/langchain_test': ['https://raw.githubusercontent.com/javovelez/langchain_test/9cf03b030d0aad1fd8cd6382a7139c02a3365138/zero_to_hero/03_using_memory.py',
#   'https://raw.githubusercontent.com/javovelez/langchain_test/9cf03b030d0aad1fd8cd6382a7139c02a3365138/zero_to_hero/02_using_chains.py'],
#  'ritikam1234/Langchain-Projects': ['https://raw.githubusercontent.com/ritikam1234/Langchain-Projects/37cd907741f9b84a0584b64e5fcdc82b67617c66/gpt3_chatbot.py'],
#  'mainul-islam-faruqi/Langchain-practice': ['https://raw.githubusercontent.com/mainul-islam-faruqi/Langchain-practice/d809658da59f972f4f5318739cee76cd37f1c6de/main.py'],
#  'cigotete/langchain_basics': ['https://raw.githubusercontent.com/cigotete/langchain_basics/98eea3beb8bb872eb47b1369e44434d54070cc1e/opinion_books.py'],
#  'raki-1203/langchain_debug': ['https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/chains/query_constructor/prompt.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/evaluation/qa/eval_prompt.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/chains/router/multi_prompt.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/evaluation/agents/trajectory_eval_prompt.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/evaluation/run_evaluators/criteria_prompt.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/chains/qa_with_sources/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/chains/prompt_selector.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/chains/question_answering/map_rerank_prompt.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/chains/router/multi_prompt_prompt.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/chains/router/multi_retrieval_prompt.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/chains/pal/math_prompt.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/chains/question_answering/stuff_prompt.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/agents/react/textworld_prompt.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/chains/natbot/prompt.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/prompts/loading.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/chains/question_answering/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/evaluation/qa/generate_prompt.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/chains/pal/colored_object_prompt.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/prompts/few_shot_with_templates.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/chains/hyde/prompts.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/prompts/chat.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/how_to_create_chatgpt_clone.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/chains/sql_database/base.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/chains/llm_checker/prompt.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/agents/conversational_chat/base.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/retrievers/document_compressors/chain_extract.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/agents/agent_toolkits/openapi/planner.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/indexes/prompts/entity_extraction.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/chains/mapreduce.py',
#   'https://raw.githubusercontent.com/raki-1203/langchain_debug/b3ad08fb2c1bcbf669f5f10452f797d19ef420a8/langchain/chains/flare/base.py'],
#  'piroyoung/example-langchain': ['https://raw.githubusercontent.com/piroyoung/example-langchain/2cc5ac5f4d2ce8619a725a2970fd407b619c958b/sandbox.py'],
#  'zaijiang/langchain-chatglm': ['https://raw.githubusercontent.com/zaijiang/langchain-chatglm/6ed5ba15167cab579e43c21717196ff3e706ccc5/server/chat/github_chat.py',
#   'https://raw.githubusercontent.com/zaijiang/langchain-chatglm/6ed5ba15167cab579e43c21717196ff3e706ccc5/configs/model_config.py',
#   'https://raw.githubusercontent.com/zaijiang/langchain-chatglm/6ed5ba15167cab579e43c21717196ff3e706ccc5/server/chat/chat.py',
#   'https://raw.githubusercontent.com/zaijiang/langchain-chatglm/6ed5ba15167cab579e43c21717196ff3e706ccc5/server/chat/knowledge_base_chat.py',
#   'https://raw.githubusercontent.com/zaijiang/langchain-chatglm/6ed5ba15167cab579e43c21717196ff3e706ccc5/chains/llmchain_with_history.py',
#   'https://raw.githubusercontent.com/zaijiang/langchain-chatglm/6ed5ba15167cab579e43c21717196ff3e706ccc5/server/chat/search_engine_chat.py'],
#  'rampadc/wxai-langchain': ['https://raw.githubusercontent.com/rampadc/wxai-langchain/f254bf480a0524ce9e01d185374091b002870ae9/examples/0.0.4/few-shot-prompt-template.py',
#   'https://raw.githubusercontent.com/rampadc/wxai-langchain/f254bf480a0524ce9e01d185374091b002870ae9/examples/0.0.4/zero-shot-prompt-template.py',
#   'https://raw.githubusercontent.com/rampadc/wxai-langchain/f254bf480a0524ce9e01d185374091b002870ae9/examples/0.0.4/prompt-template.py'],
#  'linkcheng/langchain-playground': ['https://raw.githubusercontent.com/linkcheng/langchain-playground/d0c73f2616c0cf73682882fb2d072a3a62651206/conversation_chain.py'],
#  'Atsushi-Ishii/langchain_custom': ['https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/memory/prompt.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/evaluation/qa/eval_prompt.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/chains/qa_with_sources/stuff_prompt.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/chains/qa_with_sources/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/chains/prompt_selector.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/prompts/few_shot_with_templates.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/chains/pal/math_prompt.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/agents/agent_toolkits/openapi/planner_prompt.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/chains/graph_qa/prompts.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/chains/llm_checker/prompt.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/prompts/base.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/prompts/few_shot.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/agents/react/wiki_prompt.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/chains/pal/colored_object_prompt.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/prompts/example_selector/length_based.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/chains/question_answering/map_rerank_prompt.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/chains/qa_with_sources/refine_prompts.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/chains/question_answering/stuff_prompt.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/chains/question_answering/map_reduce_prompt.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/chains/llm.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/prompts/chat.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/chains/combine_documents/refine.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/chains/constitutional_ai/prompts.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/retrievers/document_compressors/chain_extract.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/indexes/prompts/knowledge_triplet_extraction.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/indexes/prompts/entity_extraction.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/agents/react/textworld_prompt.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/chains/qa_generation/base.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/prompts/__init__.py',
#   'https://raw.githubusercontent.com/Atsushi-Ishii/langchain_custom/c374ac6f6bcd2178997e664f82a693e47573213c/langchain/prompts/loading.py']}
