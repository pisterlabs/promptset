# %% [markdown]
# # 🕸️ Scraping Results

# %%
import json
libraries = ["openai", "langchain", "cohere", "llamaindex", "guidance", "anthropic"]

print(
"""
Result Counts from Github (Collected Manually)
    openai: 71.7k
    langchain: 50.2k
    cohere: 5.1k
    guidance: 1.6k
    anthropic: 1.5k
    llamaindex: 91
"""
)

all_hrefs = []
for lib in libraries:
    with open(f'results_{lib}.json') as f:
        data = json.load(f)

    total_num_results = 0
    total_hrefs = 0

    for charCombo, results in data.items():
        num_result = results['num_results']
        hrefs = results['hrefs']

        # Convert num_result to int
        num_result = num_result.split()[0].replace(',', '')
        num_result = int(float(num_result[:-1])) if "k" in num_result else int(num_result)
        total_num_results += num_result

        # Count hrefs
        total_hrefs += len(hrefs)
        all_hrefs += hrefs

    print(f'Library: {lib}')
    print('\tTotal number of results:', total_num_results)
    print('\tTotal number of hrefs:', total_hrefs)
# Out:
# Result Counts from Github (Collected Manually)
#     openai: 71.7k
#     langchain: 50.2k
#     cohere: 5.1k
#     guidance: 1.6k
#     anthropic: 1.5k
#     llamaindex: 91
#
# Library: openai
# 	Total number of results: 33952
# 	Total number of hrefs: 18206
# Library: langchain
# 	Total number of results: 28803
# 	Total number of hrefs: 16775
# Library: cohere
# 	Total number of results: 5380
# 	Total number of hrefs: 4121
# Library: llamaindex
# 	Total number of results: 91
# 	Total number of hrefs: 91
# Library: guidance
# 	Total number of results: 1303
# 	Total number of hrefs: 1195
# Library: anthropic
# 	Total number of results: 1401
# 	Total number of hrefs: 1328

# %% [markdown]
# # 📚 Downloading All Files

# %%
import os, requests

print('\nTotal number of hrefs:', len(all_hrefs))

all_rawFileURLs = [href.replace("blob/", "").replace("https://github.com", "https://raw.githubusercontent.com") for href in all_hrefs]
for i in range(len(all_rawFileURLs)):
    if "#" in all_rawFileURLs[i]:
        all_rawFileURLs[i] = "#".join(all_rawFileURLs[i].split("#")[:-1])

root_dir = "repos"
if not os.path.exists(root_dir):
    os.mkdir(root_dir)

# count = 0
for url in all_rawFileURLs:
    url_split = url.split("/")

    # Getting repo name
    repo_name = "~".join(url_split[3:5])

    # Remove "#" from filename if it exists
    filename_addr = url_split[6:]
    filename_addr = "~".join(filename_addr)

    # repo path
    repo_path = os.path.join(root_dir, repo_name)
    if not os.path.exists(repo_path):
        os.mkdir(os.path.join(root_dir, repo_name))

    # file path
    file_path = os.path.join(repo_path, filename_addr)
    if len(file_path) > 255:
        filename_addr = filename_addr.split("~")[-1]
        file_path = os.path.join(repo_path, filename_addr)

    if not os.path.exists(file_path):
        try:
            r = requests.get(url, timeout=1)
            # Exception thrown before file is created. 
            # So, if file exists, it's safe to assume that it's been downloaded successfully.
            if r.status_code == 200:
                with open(file_path, "w") as f:
                    f.write(r.text)
            else:
                print("Error: ", r.status_code, repo_path, filename_addr)
        except Exception as e:
            print(e)
            print("Error: ", repo_path, filename_addr)

    # if count % 100 == 0:
    #     print(count, end=" ")
    # count += 1

print("Done")
# Out:
# Total number of hrefs: 41716
# Error:  404 repos/supertimmyh~vidsum pages~4_Summarizing_Video.py
# Error:  404 repos/TheseApps~Prompts gptCalls01~callGpt.py
# Error:  404 repos/rixmape~drr-chatbot cli-sample-usage.py
# Error:  404 repos/christina8711~llm_cubestacking CubeStackingAssistant.py
# Error:  404 repos/Sea-Snell~LLM_RL llm_rl_scripts~chess~gpt4~gpt4_chess_endgames.py
# Error:  404 repos/tk1363704~TA2_manager hetao_subteam1_known_norms.py
# Error:  404 repos/tk1363704~TA2_manager hetao_subteam1.py
# Error:  404 repos/JerryWestrick~KnowledgeEngineer KbServerApp~kbserver.py
# Error:  404 repos/danieljbk~calhacks-spot code~legacy~key.py
# Error:  404 repos/ken-at-kore~LG-AiBot-Prototype lg_aibot.py
# Error:  404 repos/tk1363704~TA2_manager monash_norm_detector.py
# Error:  404 repos/jayantr7~saatvaChatbot myEmbeddings.py
# Error:  404 repos/jayantr7~saatvaChatbot myEmbeddings_copy.py
# Error:  404 repos/tk1363704~TA2_manager norm_violation_detection.py
# Error:  404 repos/Leoyishou~viva output~outputTest.py
# Error:  404 repos/Sea-Snell~LLM_RL llm_rl_scripts~car_dealer~env~personality_convos.py
# Error:  404 repos/Sea-Snell~LLM_RL llm_rl_scripts~twenty_questions~env~policies.py
# Error:  404 repos/jayantr7~saatvaChatbot prompter.py
# Error:  404 repos/tk1363704~TA2_manager ranker.py
# Error:  404 repos/tk1363704~TA2_manager run_gpt3_corrector_remediator.py
# Error:  404 repos/danieljbk~calhacks-spot speech_to_cmd.py
# Error:  404 repos/danieljbk~calhacks-spot code~legacy~voice~spot.py
# Error:  404 repos/abstra-app~hackerforms-examples forms~sql_generator.py
# Error:  404 repos/Sea-Snell~LLM_RL llm_rl_scripts~twenty_questions~misc~twenty_questions_gpt4.py
# Error:  404 repos/simular-ai~OpenAGI vision.py
# Error:  404 repos/Leoyishou~viva real_tools~AskAgainTool.py
# Error:  404 repos/Leoyishou~viva chains~AsyncChain.py
# Error:  404 repos/hsushuai~LangChain-Chat-Demo chat_models~call_chat_models.py
# Error:  404 repos/hsushuai~LangChain-Chat-Demo vector_stores~call_vectorstore.py
# Error:  404 repos/BastinFlorian~RAG-GCP src~chatbot~firestore.py
# Error:  404 repos/Leoyishou~viva experiments~iteratorTest.py
# Error:  404 repos/ShelbyJenkins~langchain langchain~document_loaders~iugu.py
# Error:  404 repos/ken-at-kore~LG-AiBot-Prototype lg_aibot.py
# Error:  404 repos/Leoyishou~viva agents~multiActionAgent.py
# Error:  404 repos/jfelipenc~NexbotChat backend~nexbot.py
# Error:  404 repos/ziphell~OpenCopilot llm-server~routes~workflow~openapi_agent.py
# Error:  404 repos/reinhardtpalko~auto-ratings question-rubric-create~rubric_setup.py
# Error:  404 repos/davidlainesv~olivia-finetuning sabana_update.py
# Error:  404 repos/Leoyishou~viva agents~scheduleAgent.py
# Error:  404 repos/Leoyishou~viva viva2.py
# Error:  404 repos/ziphell~OpenCopilot llm-server~routes~workflow~workflow_controller.py
# Error:  404 repos/ziphell~OpenCopilot llm-server~routes~workflow~workflow_controller.py
# Error:  404 repos/ShelbyJenkins~langchain langchain~document_loaders~xorbits.py
# Error:  404 repos/hsushuai~LangChain-Chat-Demo embeddings~zhipuai_embeddings.py
# Error:  404 repos/danielgross~python-llm llm~main.py
# Done

# %%
import os
root_dir = "repos"
# Counting number of files
count = 0
for root, dirs, files in os.walk(root_dir):
    count += len(files)
print("Total number of files:", count)
# Out:
# Total number of files: 37887
